# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import API
from tweepy import Cursor
from datetime import datetime, date, time, timedelta
from collections import Counter
import sys
import math
import re
import pandas as pd
import time
import numpy as np

# %%
consumer_key = "T5mrPqWj3JfkftRL86S2MFEze"
consumer_secret = "BLIjrePtYXecGFIt5zlQ9xXOkRmaAwHs0HiKxVXhgWqiaOWDap"
access_key = "754570151538757634-hOHyq1pwl7acWhZWxHLeLoSpR7dQFJd"
access_secret = "YmwyFupx8uNEMVeSzYb0s0pscQRmb6xRZiPfNSCE02Uup"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
account_list = ['@UdhayavannanUvi']
ids = []
statuses=None

# %%
def get_followers_id(person):
    foloowersid = []
    count=0
    influencer=api.get_user(screen_name=person)   #screen_name
    influencer_id=influencer.id
    number_of_followers=influencer.followers_count
    print("number of followers count : ",number_of_followers,'\n','user id : ',influencer_id)
    status = tweepy.Cursor(api.followers_ids, user_id=person, tweet_mode="extended").items() #screen_name
    for i in range(0,number_of_followers):
        try:
            user=next(status)
            foloowersid.append(user)
            count += 1
        except tweepy.TweepError:
            print('error limite of twiter sleep for 15 min')
            timestamp = time.strftime("%d.%m.%Y %H:%M:%S", time.localtime())
            print(timestamp)
            if len(foloowersid)>0 :
                print('the number get until this time :', count,'all folloers count is : ',number_of_followers)
                foloowersid = np.array(str(foloowersid))
                save_followers_status(person, foloowersid)
                foloowersid = []
            time.sleep(15*60)
            next(status)
        except :
            print('end of foloowers ', count, 'all followers count is : ', number_of_followers)
            foloowersid = np.array(str(foloowersid))
            save_followers_status(person, foloowersid)
            foloowersid = []
    #save_followers_status(person, foloowersid)
    # foloowersid = np.array(map(str,foloowersid))
    return foloowersid

# %%
ids=get_followers_id(account_list[0])
print("follower ids :",ids)
# Out:
# number of followers count :  34
#  user id :  754570151538757634
# follower ids : [755317824638246912, 1225279175302344705, 999254204932763648, 1167128409085890560, 1142386746694332416, 273423046, 1047311216937508864, 1084446431987957761, 739090111338401792, 942032173388898304, 1042276383098003456, 1026048180704575488, 1009850528765902848, 953189299599503360, 1009783190800789504, 909379865559756802, 992414541186191361, 719838504327352320, 945594464063467520, 930744964627120128, 876428483408273413, 822913800529727488, 820549404511916032, 800347753133928448, 815091329793490944, 1922516666, 755024958712012801, 3274509678, 786065106530603008, 756102342924046336, 740865625233334272, 757531961426489344, 2409048883, 752528322270081024]

# %%
#if (len(account_list) > 1):
#  account_list = sys.argv[1:]
#else:
#  print("Please provide a list of usernames at the command line.")
#  sys.exit(0)

# %%
#description
if len(account_list) > 0:
  for target in account_list:
    print("Getting data for " + target)
    item = api.get_user(target)
    print("name: " + item.name)
    print("screen_name: " + item.screen_name)
    print("description: " + item.description)
    if(len(item.description)>0):
                description=1
    else:
                description=0
    print("statuses_count: " , item.statuses_count)
    print("friends_count: " , item.friends_count)
    print("followers_count: " , item.followers_count)
    print("favourites count:",item.favourites_count)
    print("verified: ",str(item.verified))
    print("lang: ",str(item.lang))
    if(item.statuses_count!=0):
     try:
      statuses=str(item.status)
     except:
      statuses=None
    print("status: ",statuses)
    print("listed count: ",item.listed_count)
    print("default_profile: ",str(item.default_profile))
    print("default_image: ",str(item.default_profile_image))
    print("has extended profile: ",str(item.has_extended_profile))
    print("id :",item.id)
    print("id_str :",str(item.id_str))
    print("location :",str(item.location))
    print("url : ",str(item.url))
    #print("followers",item.followers)
    followers=item.followers_count
    following=item.friends_count
    tweets = item.statuses_count
    account_created_date = item.created_at
    print("creation date",account_created_date)
    print("created date = ",account_created_date)
    delta = datetime.utcnow() - account_created_date
    print(delta)
    account_age_days = delta.days
    print("Account age (in days): " + str(account_age_days))
    if account_age_days > 0:
      print("Average tweets per day: " + "%.2f"%(float(tweets)/float(account_age_days)))

    hashtags = []
    mentions = []
    tweet_count = 0
    sum=0
    hash=0
    end_date = datetime.utcnow() - timedelta(days=30)
    for status in Cursor(api.user_timeline, id=target).items():
      tweet_count += 1
      if hasattr(status, "entities"):
        entities = status.entities
    #    print(status.entities)
        if "hashtags" in entities:
          for ent in entities["hashtags"]:
            if ent is not None:
              if "text" in ent:
                hashtag = ent["text"]
                if hashtag is not None:
                  hashtags.append(hashtag)
                  hash+=1
        if "user_mentions" in entities:
          for ent in entities["user_mentions"]:
            if ent is not None:
              if "screen_name" in ent:
                name = ent["screen_name"]
                if name is not None:
                  mentions.append(name)
                  sum+=1
    #  if status.created_at < end_date:
    #    break
    print("tweet count",tweet_count)
    print()
    unique=0
    unique=len(set(mentions))
    print(unique)
    print(sum)
    if(tweet_count==0):
        mentions_ratio=0
    else:
        mentions_ratio="%.10f"%(sum/tweet_count)
    if(sum==0):
        unique_mentions=0
    else:
        unique_mentions="%.10f"%(unique/sum)

    print()
    print("Most used hashtags:")
    for item, count in Counter(hashtags).most_common(10):
      print(item + "\t" + str(count))
    if(tweets==0):
     hashtag_ratio=0.0
    else:
     hashtag_ratio="%.10f"%(hash/tweets)
    reputation="%.10f"%(followers/(following+followers))
    print("reputation = ",reputation,"\nmentions raitio = ",mentions_ratio,"\nhashtag_ratio =",hashtag_ratio)
    print("unique mentions =",unique_mentions)
    print("All done. Processed " + str(tweet_count) + " tweets.")

    #extract tweets and store it in list
    alltweets = []
    tweet_time=[]
    new_tweets = api.user_timeline(screen_name = target,count=200)
    #print(type(new_tweets))
    for tweet in new_tweets:
        alltweets.append(tweet.text)
        print(tweet.created_at)
        tweet_time.append(tweet.created_at)
        print(tweet.retweet_count)
    total=0
    for i in range(1,tweet_count):
        total+=(tweet_time[i-1]-tweet_time[i]).days
    print("total intertweet_delay",total)
    if(tweet_count==0):
     mean=0.0
    else:
     mean=float("%.10f"%(total/tweet_count))             #mean of inter tweet delay
    print("mean_of_intertweet_delay ", mean)

    total=0
    for i in range(tweet_count):
        total+=((tweet_time[i]).day-float(mean))**2
    if(tweet_count==0):
     variance=0.0
    else:
     variance=total/tweet_count
    sd=float("%.10f"%(math.sqrt(variance)))         # sd of intertweet delay
    print("sd of intertweet delay ",sd)
    avg_tweets_day=float("%.10f"%(tweet_count/account_age_days))
    avg_tweets_week=float("%.10f"%(tweet_count/(account_age_days/7)))
    print("avg_tweets day and week" , avg_tweets_day," ",avg_tweets_week)

    url_count=0
    for tweet in new_tweets:
        if(len(tweet.entities["urls"])>0):
                url_string=tweet.entities["urls"][0]['expanded_url']
                x=re.search("^https://twitter\.com.*",url_string)
                print("twitter urls :")
                if(x):
                    #url_count+=1
                    print(tweet.entities["urls"][0]['url'])
                    print(tweet.entities,"\n\n")

                else:
                    print("url posted by user: ")
                    url_count+=len(tweet.entities["urls"])
                    #print(tweet.entities)
                    print(tweet.entities["urls"][0]['url'])
    print("url count is ", url_count)
    if(tweet_count==0):
     url_ratio=0.0
    else:
     url_ratio=float("%.10f"%(url_count/tweet_count))
    print("url ratio is ",url_ratio)



#    print("list count", item.list_count)
    sum=0
    count=0
    for tweet in new_tweets:
    #    alltweets.append(tweet.text)
    #    print(tweet.created_at)
    #    tweet_time.append(tweet.created_at)
        count+=1
    #    print(tweet.retweet_count)
        retweet_count=tweet.retweet_count
        sum+=retweet_count/followers    #rt rate for each tweet
    if(count==0):
     retweet_rate=0.0
    else:
     retweet_rate  =float("%.10f"%(sum/count))
    print("retweet rate is ",retweet_rate)

    replies=0
    for tweet in new_tweets:
        print(tweet.in_reply_to_screen_name)
        #break
        if(tweet.in_reply_to_screen_name!=None):
            replies+=1
    if(count==0):
     reply_rate=0.0
    else:
     reply_rate  =float("%.10f"%(replies/count))
    print("retweet rate is ",reply_rate)

  for target in account_list:
    print("Getting data for " + target)
    item = api.get_user(target)
    if(item.verified==False):
            verified=0
    else:
        verified=1
    print(item.verified)
    print(item.listed_count)
# Out:
# Getting data for @UdhayavannanUvi
# name: A.Udhayavannan
# screen_name: UdhayavannanUvi
# description:
# statuses_count:  48
# friends_count:  109
# followers_count:  34
# favourites count: 18
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Thu Oct 24 05:34:47 +0000 2019', 'id': 1187241001343078400, 'id_str': '1187241001343078400', 'text': '@No_PlasticWaste @minderoo @TEDchris hello', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'No_PlasticWaste', 'name': 'No Plastic Waste', 'id': 1170057621832777728, 'id_str': '1170057621832777728', 'indices': [0, 16]}, {'screen_name': 'minderoo', 'name': 'Minderoo Foundation', 'id': 1853845165, 'id_str': '1853845165', 'indices': [17, 26]}, {'screen_name': 'TEDchris', 'name': 'Chris Anderson', 'id': 14761795, 'id_str': '14761795', 'indices': [27, 36]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1181751063000604672, 'in_reply_to_status_id_str': '1181751063000604672', 'in_reply_to_user_id': 1170057621832777728, 'in_reply_to_user_id_str': '1170057621832777728', 'in_reply_to_screen_name': 'No_PlasticWaste', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 10, 24, 5, 34, 47), id=1187241001343078400, id_str='1187241001343078400', text='@No_PlasticWaste @minderoo @TEDchris hello', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'No_PlasticWaste', 'name': 'No Plastic Waste', 'id': 1170057621832777728, 'id_str': '1170057621832777728', 'indices': [0, 16]}, {'screen_name': 'minderoo', 'name': 'Minderoo Foundation', 'id': 1853845165, 'id_str': '1853845165', 'indices': [17, 26]}, {'screen_name': 'TEDchris', 'name': 'Chris Anderson', 'id': 14761795, 'id_str': '14761795', 'indices': [27, 36]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1181751063000604672, in_reply_to_status_id_str='1181751063000604672', in_reply_to_user_id=1170057621832777728, in_reply_to_user_id_str='1170057621832777728', in_reply_to_screen_name='No_PlasticWaste', geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  False
# has extended profile:  True
# id : 754570151538757634
# id_str : 754570151538757634
# location :
# url :  None
# creation date 2016-07-17 06:55:18
# created date =  2016-07-17 06:55:18
# 1426 days, 20:39:52.347126
# Account age (in days): 1426
# Average tweets per day: 0.03
# tweet count 48
#
# 45
# 80
#
# Most used hashtags:
# AvengersEndgame	2
# RiseofSkywalker	1
# CHEvsJAI	1
# vivoProKabaddi	1
# IsseToughKuchNahi	1
# ironman	1
# captainamerica	1
# Whateverittakes	1
# SPICinemas	1
# endgame	1
# reputation =  0.2377622378
# mentions raitio =  1.6666666667
# hashtag_ratio = 0.2708333333
# unique mentions = 0.5625000000
# All done. Processed 48 tweets.
# 2019-10-24 05:34:47
# 0
# 2019-10-24 04:37:42
# 0
# 2019-08-21 16:23:05
# 0
# 2019-07-10 14:21:34
# 0
# 2019-05-28 04:07:27
# 0
# 2019-05-27 03:29:58
# 0
# 2019-05-27 03:24:59
# 0
# 2019-04-25 14:51:13
# 0
# 2019-04-24 01:27:16
# 0
# 2019-04-23 15:59:15
# 0
# 2019-04-23 15:58:48
# 0
# 2019-04-23 15:58:40
# 0
# 2019-04-23 15:58:21
# 0
# 2019-04-23 15:58:07
# 0
# 2019-04-23 15:57:59
# 0
# 2019-04-23 15:57:52
# 0
# 2019-04-23 15:57:46
# 0
# 2019-04-23 15:57:38
# 0
# 2019-04-23 15:57:30
# 0
# 2019-04-23 15:57:21
# 0
# 2019-04-23 15:57:08
# 0
# 2019-04-23 15:56:54
# 0
# 2019-04-23 15:56:48
# 0
# 2019-04-23 15:56:19
# 0
# 2019-04-23 15:55:44
# 0
# 2019-04-23 15:55:28
# 0
# 2019-04-23 15:55:18
# 0
# 2019-04-23 15:55:07
# 0
# 2019-04-23 15:54:57
# 0
# 2019-04-23 15:54:48
# 0
# 2019-04-23 15:54:39
# 0
# 2019-04-23 15:54:30
# 0
# 2019-04-23 15:54:21
# 0
# 2019-04-23 15:54:10
# 0
# 2019-04-23 15:53:52
# 0
# 2019-04-23 15:53:43
# 0
# 2019-04-23 15:53:36
# 0
# 2019-04-23 15:53:26
# 0
# 2019-04-23 15:53:14
# 0
# 2019-04-23 15:53:02
# 0
# 2019-04-23 12:54:42
# 0
# 2019-04-23 11:54:02
# 0
# 2019-04-23 11:45:08
# 0
# 2019-04-23 06:56:27
# 0
# 2019-04-22 15:34:29
# 0
# 2019-04-22 15:02:05
# 0
# 2019-04-19 00:44:04
# 0
# 2019-03-14 16:20:37
# 0
# total intertweet_delay 219
# mean_of_intertweet_delay  4.5625
# sd of intertweet delay  18.3772320073
# avg_tweets day and week 0.0336605891   0.2356241234
# twitter urls :
# url posted by user:
# https://t.co/LtkO3psEBX
# twitter urls :
# https://t.co/HRh0zlKv3S
# {'hashtags': [{'text': 'Whateverittakes', 'indices': [11, 27]}, {'text': 'AvengersEndgame', 'indices': [40, 56]}], 'symbols': [], 'user_mentions': [{'screen_name': 'GKcinemas', 'name': 'Ruban Mathivanan', 'id': 128495725, 'id_str': '128495725', 'indices': [0, 10]}], 'urls': [{'url': 'https://t.co/HRh0zlKv3S', 'expanded_url': 'https://twitter.com/i/web/status/1120657078115164162', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}
#
#
# twitter urls :
# https://t.co/2ZK0rvycom
# {'hashtags': [{'text': 'Thor', 'indices': [57, 62]}, {'text': 'Loki', 'indices': [94, 99]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ForumVijayaMall', 'name': 'TheForumVijayaMall', 'id': 1006089008, 'id_str': '1006089008', 'indices': [0, 16]}, {'screen_name': 'SPICinemas', 'name': 'S P I C i n e m a s', 'id': 919079586, 'id_str': '919079586', 'indices': [17, 28]}], 'urls': [{'url': 'https://t.co/2ZK0rvycom', 'expanded_url': 'https://twitter.com/i/web/status/1120350168258187264', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [101, 124]}]}
#
#
# twitter urls :
# https://t.co/9culWXKUHO
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'NASA', 'name': 'NASA', 'id': 11348282, 'id_str': '11348282', 'indices': [8, 13]}, {'screen_name': 'Iron_Man', 'name': 'Iron Man', 'id': 570218986, 'id_str': '570218986', 'indices': [32, 41]}, {'screen_name': 'Avengers', 'name': 'The Avengers', 'id': 393852070, 'id_str': '393852070', 'indices': [71, 80]}], 'urls': [{'url': 'https://t.co/9culWXKUHO', 'expanded_url': 'https://twitter.com/i/web/status/1106228648732819457', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}
#
#
# url count is  1
# url ratio is  0.0208333333
# retweet rate is  0.0
# No_PlasticWaste
# None
# JaipurPanthers
# _PVRCinemas
# None
# None
# None
# None
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# VettriTheatres
# GKcinemas
# SPICinemas
# GKcinemas
# ForumVijayaMall
# massguna06gmai1
# GoogleStadia
# None
# retweet rate is  0.875
# Getting data for @UdhayavannanUvi
# False
# 0

# %%
tweet_df = pd.DataFrame({'Tweet': alltweets})
tweet_df
# Out:
#                                                 Tweet
# 0          @No_PlasticWaste @minderoo @TEDchris hello
# 1           #RiseofSkywalker  https://t.co/LtkO3psEBX
# 2   @JaipurPanthers Even the commentary says. But ...
# 3                                   @_PVRCinemas puli
# 4    @CarnivalCine movie release date  30 or 31 ?????
# 5   @CarnivalCine Godzilla movie Evp la viduvingal...
# 6   @CarnivalCine When will you release the ticket...
# 7   @CarnivalCine #ironman dies and #captainameric...
# 8   @SPICinemas @hackiz @vrlokesh1992 i dont need ...
# 9          @SPICinemas @BagathSanju Enough already n8
# 10                     @SPICinemas @sbk585 already n8
# 11            @SPICinemas @bnikhileshwarre already n8
# 12              @SPICinemas @fosterjack631 already n8
# 13              @SPICinemas @gokulrock1702 already n8
# 14            @SPICinemas @SudarshanSivak1 already n8
# 15              @SPICinemas @gokul60699263 already n8
# 16                @SPICinemas @KrizzArvind already n8
# 17                 @SPICinemas @rafi200331 already n8
# 18            @SPICinemas @SanjayC91429472 already n8
# 19              @SPICinemas @Surya83740256 already n8
# 20                    @SPICinemas @Rogshii already n8
# 21            @SPICinemas @Yashwan48643397 already n8
# 22  @SPICinemas @PrakashKathir7 @TheCinemabySPI al...
# 23   @SPICinemas @saravana_assr In Chennai already n8
# 24             @SPICinemas @S__ViNoDhKuMaR already n8
# 25            @SPICinemas @IlayaBharathi14 already n8
# 26                  @SPICinemas @raaghul06 already n8
# 27            @SPICinemas @Anbulogachandr1 already n8
# 28               @SPICinemas @tarun_aadith already n8
# 29                  @SPICinemas @arif_1305 already n8
# 30                  @SPICinemas @Bheembwoy already n8
# 31                @SPICinemas @AkashAk2812 already n8
# 32                @SPICinemas @siddhubalaj already n8
# 33                 @SPICinemas @Havinash20 already n8
# 34                   @SPICinemas @mano3493 already n8
# 35            @SPICinemas @AjayBha23009929 already n8
# 36              @SPICinemas @VinodhSundeep already n8
# 37                  @SPICinemas @iPradeepD already n8
# 38              @SPICinemas @VoiceOutforus already n8
# 39         @SPICinemas @VmsRohith @Rogshii already n8
# 40  @VettriTheatres Online tickets????????????????...
# 41  @GKcinemas #Whateverittakes Pls release #Aveng...
# 42  @SPICinemas @Marvel_India @IMAX #SPICinemas co...
# 43  @GKcinemas When will u release the tickets for...
# 44  @ForumVijayaMall @SPICinemas 1.SpaceStone - Te...
# 45  @massguna06gmai1 @rakkicinemas @MarvelStudios ...
# 46  @GoogleStadia @Google Am i suppose to buy 2 st...
# 47  Thank u @NASA  for bringing our @Iron_Man tony...

# %%
extract_data=[[description,verified,account_age_days,followers,mentions_ratio,url_ratio,hashtag_ratio,retweet_rate,mean,sd,avg_tweets_day,avg_tweets_week]]
#print(extract_data)
extract_df=pd.DataFrame(extract_data,columns=["description","verified","age","followers","mentions","url_ratio","hashtag","retweet_rate","mean_of_intertweet_delay","SD","avg_tweets_day","avg_tweeets_week"])
extract_df
# Out:
#    description  verified   age  followers      mentions  url_ratio  \
# 0            0         0  1426         34  1.6666666667   0.020833
#
#         hashtag  retweet_rate  mean_of_intertweet_delay         SD  \
# 0  0.2708333333           0.0                    4.5625  18.377232
#
#    avg_tweets_day  avg_tweeets_week
# 0        0.033661          0.235624

# %%
#id=ids[0]

followers_df = pd.DataFrame()
final=[]

# %%
if len(ids) > 0:
  for person in ids:
    print("\n")
    print("user_id is ",person)
    item=api.get_user(user_id=person)   #screen_name
    #item = influencer.screen_name
    print("name: " + item.name)
    print("screen_name: " + item.screen_name)
    print("description: " + item.description)
    if(len(item.description)>0):
                description=1
    else:
                description=0
    print("statuses_count: " , item.statuses_count)
    print("friends_count: " , item.friends_count)
    print("followers_count: " , item.followers_count)
    print("favourites count:",item.favourites_count)
    print("verified: ",item.verified)
    print("lang: ",item.lang)
    if(item.statuses_count!=0):
     try:
      statuses=str(item.status)
     except:
      statuses=None
    print("status: ",statuses)
    print("listed count: ",item.listed_count)
    print("default_profile: ",str(item.default_profile))
    print("default_image: ",str(item.default_profile_image))
    print("has extended profile: ",str(item.has_extended_profile))
    print("id :",item.id)
    print("id_str :",str(item.id_str))
    print("location :",str(item.location))
    print("url : ",str(item.url))
#  print("followers",item.followers)
    followers=item.followers_count
    following=item.friends_count
    tweets = item.statuses_count
    account_created_date = item.created_at
    print("created date = ",account_created_date)
    delta = datetime.utcnow() - account_created_date
    print(delta)
    account_age_days = delta.days
    print("Account age (in days): " + str(account_age_days))

    if(item.verified==False):
            verified=0
    else:
        verified=1
    print(item.verified)
    followers_data=[]
    #followers_data=pd.Series([item.id,item.id_str,item.screen_name,item.location,item.description,item.url,item.followers_count,item.friends_count,item.listed_count,account_created_date,item.favourites_count,item.verified,item.statuses_count,item.lang,"none",str(item.default_profile),str(item.default_profile_image),str(item.has_extended_profile),item.name])
    followers_data=[item.id,item.id_str,item.screen_name,item.location,item.description,item.url,item.followers_count,item.friends_count,item.listed_count,account_created_date,item.favourites_count,item.verified,item.statuses_count,item.lang,statuses,str(item.default_profile),str(item.default_profile_image),str(item.has_extended_profile),item.name]
    print("followers data is ",followers_data)
    final.append(followers_data)
    #followers_df=pd.concat([followers_data,followers_df],ignore_index=True)
#    followers_df.append(followers_data,ignore_index=True)
# Out:
# user_id is  755317824638246912
# name: Vinuvarsidh
# screen_name: vinuvarsidh
# description:
# statuses_count:  7
# friends_count:  95
# followers_count:  7
# favourites count: 23
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Sat May 16 13:28:01 +0000 2020', 'id': 1261649609908031489, 'id_str': '1261649609908031489', 'text': '@realmemobiles Realme devices are great ❣️ . Keep focusing more on quality than quantity, and keep optimising ur UI… https://t.co/4nSU6BPWBt', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realmemobiles', 'name': 'realme', 'id': 986828524936990721, 'id_str': '986828524936990721', 'indices': [0, 14]}], 'urls': [{'url': 'https://t.co/4nSU6BPWBt', 'expanded_url': 'https://twitter.com/i/web/status/1261649609908031489', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1261227320259592197, 'in_reply_to_status_id_str': '1261227320259592197', 'in_reply_to_user_id': 986828524936990721, 'in_reply_to_user_id_str': '986828524936990721', 'in_reply_to_screen_name': 'realmemobiles', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 5, 16, 13, 28, 1), id=1261649609908031489, id_str='1261649609908031489', text='@realmemobiles Realme devices are great ❣️ . Keep focusing more on quality than quantity, and keep optimising ur UI… https://t.co/4nSU6BPWBt', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realmemobiles', 'name': 'realme', 'id': 986828524936990721, 'id_str': '986828524936990721', 'indices': [0, 14]}], 'urls': [{'url': 'https://t.co/4nSU6BPWBt', 'expanded_url': 'https://twitter.com/i/web/status/1261649609908031489', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1261227320259592197, in_reply_to_status_id_str='1261227320259592197', in_reply_to_user_id=986828524936990721, in_reply_to_user_id_str='986828524936990721', in_reply_to_screen_name='realmemobiles', geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  True
# has extended profile:  False
# id : 755317824638246912
# id_str : 755317824638246912
# location :
# url :  None
# created date =  2016-07-19 08:26:17
# 1424 days, 19:08:58.364577
# Account age (in days): 1424
# False
# followers data is  [755317824638246912, '755317824638246912', 'vinuvarsidh', '', '', None, 7, 95, 0, datetime.datetime(2016, 7, 19, 8, 26, 17), 23, False, 7, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Sat May 16 13:28:01 +0000 2020\', \'id\': 1261649609908031489, \'id_str\': \'1261649609908031489\', \'text\': \'@realmemobiles Realme devices are great ❣️ . Keep focusing more on quality than quantity, and keep optimising ur UI… https://t.co/4nSU6BPWBt\', \'truncated\': True, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'realmemobiles\', \'name\': \'realme\', \'id\': 986828524936990721, \'id_str\': \'986828524936990721\', \'indices\': [0, 14]}], \'urls\': [{\'url\': \'https://t.co/4nSU6BPWBt\', \'expanded_url\': \'https://twitter.com/i/web/status/1261649609908031489\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': 1261227320259592197, \'in_reply_to_status_id_str\': \'1261227320259592197\', \'in_reply_to_user_id\': 986828524936990721, \'in_reply_to_user_id_str\': \'986828524936990721\', \'in_reply_to_screen_name\': \'realmemobiles\', \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2020, 5, 16, 13, 28, 1), id=1261649609908031489, id_str=\'1261649609908031489\', text=\'@realmemobiles Realme devices are great ❣️ . Keep focusing more on quality than quantity, and keep optimising ur UI… https://t.co/4nSU6BPWBt\', truncated=True, entities={\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'realmemobiles\', \'name\': \'realme\', \'id\': 986828524936990721, \'id_str\': \'986828524936990721\', \'indices\': [0, 14]}], \'urls\': [{\'url\': \'https://t.co/4nSU6BPWBt\', \'expanded_url\': \'https://twitter.com/i/web/status/1261649609908031489\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, source=\'Twitter for Android\', source_url=\'http://twitter.com/download/android\', in_reply_to_status_id=1261227320259592197, in_reply_to_status_id_str=\'1261227320259592197\', in_reply_to_user_id=986828524936990721, in_reply_to_user_id_str=\'986828524936990721\', in_reply_to_screen_name=\'realmemobiles\', geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang=\'en\')', 'True', 'True', 'False', 'Vinuvarsidh']
#
#
# user_id is  1225279175302344705
# name: Terminator
# screen_name: Terminatorz_
# description:
# statuses_count:  2
# friends_count:  6
# followers_count:  1
# favourites count: 0
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Thu Feb 13 04:10:15 +0000 2020', 'id': 1227807170260951045, 'id_str': '1227807170260951045', 'text': 'recently bought note 8 pro, and this is the best phone to buy under 15k . @note8pro , @mi #note8pro ,#mifan', 'truncated': False, 'entities': {'hashtags': [{'text': 'note8pro', 'indices': [90, 99]}, {'text': 'mifan', 'indices': [101, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'note8pro', 'name': 'Note8pro', 'id': 1239148356141711360, 'id_str': '1239148356141711360', 'indices': [74, 83]}, {'screen_name': 'mi', 'name': 'محمد', 'id': 259918248, 'id_str': '259918248', 'indices': [86, 89]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 2, 13, 4, 10, 15), id=1227807170260951045, id_str='1227807170260951045', text='recently bought note 8 pro, and this is the best phone to buy under 15k . @note8pro , @mi #note8pro ,#mifan', truncated=False, entities={'hashtags': [{'text': 'note8pro', 'indices': [90, 99]}, {'text': 'mifan', 'indices': [101, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'note8pro', 'name': 'Note8pro', 'id': 1239148356141711360, 'id_str': '1239148356141711360', 'indices': [74, 83]}, {'screen_name': 'mi', 'name': 'محمد', 'id': 259918248, 'id_str': '259918248', 'indices': [86, 89]}], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  True
# has extended profile:  False
# id : 1225279175302344705
# id_str : 1225279175302344705
# location :
# url :  None
# created date =  2020-02-06 04:45:06
# 127 days, 22:50:09.900576
# Account age (in days): 127
# False
# followers data is  [1225279175302344705, '1225279175302344705', 'Terminatorz_', '', '', None, 1, 6, 0, datetime.datetime(2020, 2, 6, 4, 45, 6), 0, False, 2, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Thu Feb 13 04:10:15 +0000 2020\', \'id\': 1227807170260951045, \'id_str\': \'1227807170260951045\', \'text\': \'recently bought note 8 pro, and this is the best phone to buy under 15k . @note8pro , @mi #note8pro ,#mifan\', \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'note8pro\', \'indices\': [90, 99]}, {\'text\': \'mifan\', \'indices\': [101, 107]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'note8pro\', \'name\': \'Note8pro\', \'id\': 1239148356141711360, \'id_str\': \'1239148356141711360\', \'indices\': [74, 83]}, {\'screen_name\': \'mi\', \'name\': \'محمد\', \'id\': 259918248, \'id_str\': \'259918248\', \'indices\': [86, 89]}], \'urls\': []}, \'source\': \'<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2020, 2, 13, 4, 10, 15), id=1227807170260951045, id_str=\'1227807170260951045\', text=\'recently bought note 8 pro, and this is the best phone to buy under 15k . @note8pro , @mi #note8pro ,#mifan\', truncated=False, entities={\'hashtags\': [{\'text\': \'note8pro\', \'indices\': [90, 99]}, {\'text\': \'mifan\', \'indices\': [101, 107]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'note8pro\', \'name\': \'Note8pro\', \'id\': 1239148356141711360, \'id_str\': \'1239148356141711360\', \'indices\': [74, 83]}, {\'screen_name\': \'mi\', \'name\': \'محمد\', \'id\': 259918248, \'id_str\': \'259918248\', \'indices\': [86, 89]}], \'urls\': []}, source=\'Twitter Web App\', source_url=\'https://mobile.twitter.com\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang=\'en\')', 'True', 'True', 'False', 'Terminator']
#
#
# user_id is  999254204932763648
# name: Prabhu
# screen_name: Imprabhu15
# description:
# statuses_count:  8
# friends_count:  171
# followers_count:  19
# favourites count: 62
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Sat Dec 14 08:00:27 +0000 2019', 'id': 1205759440806244352, 'id_str': '1205759440806244352', 'text': 'RT @sachin_rt: எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\n\nசென்னை டெஸ்ட் தொடரின் போது \nTaj Coromandel ஊழியர் ஒரு…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'sachin_rt', 'name': 'Sachin Tendulkar', 'id': 135421739, 'id_str': '135421739', 'indices': [3, 13]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Dec 14 07:57:54 +0000 2019', 'id': 1205758801334296577, 'id_str': '1205758801334296577', 'text': 'எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\n\nசென்னை டெஸ்ட் தொடரின் போது \nTaj Coromandel ஊ… https://t.co/L0O4rfLxMO', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/L0O4rfLxMO', 'expanded_url': 'https://twitter.com/i/web/status/1205758801334296577', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1205757235407671296, 'in_reply_to_status_id_str': '1205757235407671296', 'in_reply_to_user_id': 135421739, 'in_reply_to_user_id_str': '135421739', 'in_reply_to_screen_name': 'sachin_rt', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 4950, 'favorite_count': 18660, 'favorited': False, 'retweeted': False, 'lang': 'ta'}, 'is_quote_status': False, 'retweet_count': 4950, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ta'}, created_at=datetime.datetime(2019, 12, 14, 8, 0, 27), id=1205759440806244352, id_str='1205759440806244352', text='RT @sachin_rt: எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\n\nசென்னை டெஸ்ட் தொடரின் போது \nTaj Coromandel ஊழியர் ஒரு…', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'sachin_rt', 'name': 'Sachin Tendulkar', 'id': 135421739, 'id_str': '135421739', 'indices': [3, 13]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, retweeted_status=Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Sat Dec 14 07:57:54 +0000 2019', 'id': 1205758801334296577, 'id_str': '1205758801334296577', 'text': 'எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\n\nசென்னை டெஸ்ட் தொடரின் போது \nTaj Coromandel ஊ… https://t.co/L0O4rfLxMO', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/L0O4rfLxMO', 'expanded_url': 'https://twitter.com/i/web/status/1205758801334296577', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1205757235407671296, 'in_reply_to_status_id_str': '1205757235407671296', 'in_reply_to_user_id': 135421739, 'in_reply_to_user_id_str': '135421739', 'in_reply_to_screen_name': 'sachin_rt', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 4950, 'favorite_count': 18660, 'favorited': False, 'retweeted': False, 'lang': 'ta'}, created_at=datetime.datetime(2019, 12, 14, 7, 57,  ...
# listed count:  0
# default_profile:  True
# default_image:  False
# has extended profile:  True
# id : 999254204932763648
# id_str : 999254204932763648
# location : Tiruvannamalai, India
# url :  None
# created date =  2018-05-23 11:42:22
# 751 days, 15:52:54.425812
# Account age (in days): 751
# False
# followers data is  [999254204932763648, '999254204932763648', 'Imprabhu15', 'Tiruvannamalai, India', '', None, 19, 171, 0, datetime.datetime(2018, 5, 23, 11, 42, 22), 62, False, 8, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Sat Dec 14 08:00:27 +0000 2019\', \'id\': 1205759440806244352, \'id_str\': \'1205759440806244352\', \'text\': \'RT @sachin_rt: எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\\n\\nசென்னை டெஸ்ட் தொடரின் போது \\nTaj Coromandel ஊழியர் ஒரு…\', \'truncated\': False, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'sachin_rt\', \'name\': \'Sachin Tendulkar\', \'id\': 135421739, \'id_str\': \'135421739\', \'indices\': [3, 13]}], \'urls\': []}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'retweeted_status\': {\'created_at\': \'Sat Dec 14 07:57:54 +0000 2019\', \'id\': 1205758801334296577, \'id_str\': \'1205758801334296577\', \'text\': \'எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\\n\\nசென்னை டெஸ்ட் தொடரின் போது \\nTaj Coromandel ஊ… https://t.co/L0O4rfLxMO\', \'truncated\': True, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/L0O4rfLxMO\', \'expanded_url\': \'https://twitter.com/i/web/status/1205758801334296577\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, \'source\': \'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>\', \'in_reply_to_status_id\': 1205757235407671296, \'in_reply_to_status_id_str\': \'1205757235407671296\', \'in_reply_to_user_id\': 135421739, \'in_reply_to_user_id_str\': \'135421739\', \'in_reply_to_screen_name\': \'sachin_rt\', \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 4950, \'favorite_count\': 18660, \'favorited\': False, \'retweeted\': False, \'lang\': \'ta\'}, \'is_quote_status\': False, \'retweet_count\': 4950, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'ta\'}, created_at=datetime.datetime(2019, 12, 14, 8, 0, 27), id=1205759440806244352, id_str=\'1205759440806244352\', text=\'RT @sachin_rt: எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\\n\\nசென்னை டெஸ்ட் தொடரின் போது \\nTaj Coromandel ஊழியர் ஒரு…\', truncated=False, entities={\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'sachin_rt\', \'name\': \'Sachin Tendulkar\', \'id\': 135421739, \'id_str\': \'135421739\', \'indices\': [3, 13]}], \'urls\': []}, source=\'Twitter for Android\', source_url=\'http://twitter.com/download/android\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, retweeted_status=Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Sat Dec 14 07:57:54 +0000 2019\', \'id\': 1205758801334296577, \'id_str\': \'1205758801334296577\', \'text\': \'எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\\n\\nசென்னை டெஸ்ட் தொடரின் போது \\nTaj Coromandel ஊ… https://t.co/L0O4rfLxMO\', \'truncated\': True, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/L0O4rfLxMO\', \'expanded_url\': \'https://twitter.com/i/web/status/1205758801334296577\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, \'source\': \'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>\', \'in_reply_to_status_id\': 120575 ...
#
#
# user_id is  1167128409085890560
# name: Venkadesh Kulaikather
# screen_name: VenkadeshK10
# description:
# statuses_count:  0
# friends_count:  13
# followers_count:  5
# favourites count: 0
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Sat Dec 14 08:00:27 +0000 2019', 'id': 1205759440806244352, 'id_str': '1205759440806244352', 'text': 'RT @sachin_rt: எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\n\nசென்னை டெஸ்ட் தொடரின் போது \nTaj Coromandel ஊழியர் ஒரு…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'sachin_rt', 'name': 'Sachin Tendulkar', 'id': 135421739, 'id_str': '135421739', 'indices': [3, 13]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Dec 14 07:57:54 +0000 2019', 'id': 1205758801334296577, 'id_str': '1205758801334296577', 'text': 'எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\n\nசென்னை டெஸ்ட் தொடரின் போது \nTaj Coromandel ஊ… https://t.co/L0O4rfLxMO', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/L0O4rfLxMO', 'expanded_url': 'https://twitter.com/i/web/status/1205758801334296577', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1205757235407671296, 'in_reply_to_status_id_str': '1205757235407671296', 'in_reply_to_user_id': 135421739, 'in_reply_to_user_id_str': '135421739', 'in_reply_to_screen_name': 'sachin_rt', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 4950, 'favorite_count': 18660, 'favorited': False, 'retweeted': False, 'lang': 'ta'}, 'is_quote_status': False, 'retweet_count': 4950, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ta'}, created_at=datetime.datetime(2019, 12, 14, 8, 0, 27), id=1205759440806244352, id_str='1205759440806244352', text='RT @sachin_rt: எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\n\nசென்னை டெஸ்ட் தொடரின் போது \nTaj Coromandel ஊழியர் ஒரு…', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'sachin_rt', 'name': 'Sachin Tendulkar', 'id': 135421739, 'id_str': '135421739', 'indices': [3, 13]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, retweeted_status=Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Sat Dec 14 07:57:54 +0000 2019', 'id': 1205758801334296577, 'id_str': '1205758801334296577', 'text': 'எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\n\nசென்னை டெஸ்ட் தொடரின் போது \nTaj Coromandel ஊ… https://t.co/L0O4rfLxMO', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/L0O4rfLxMO', 'expanded_url': 'https://twitter.com/i/web/status/1205758801334296577', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1205757235407671296, 'in_reply_to_status_id_str': '1205757235407671296', 'in_reply_to_user_id': 135421739, 'in_reply_to_user_id_str': '135421739', 'in_reply_to_screen_name': 'sachin_rt', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 4950, 'favorite_count': 18660, 'favorited': False, 'retweeted': False, 'lang': 'ta'}, created_at=datetime.datetime(2019, 12, 14, 7, 57,  ...
# listed count:  0
# default_profile:  True
# default_image:  False
# has extended profile:  True
# id : 1167128409085890560
# id_str : 1167128409085890560
# location : Tirunelveli,TamilNadu,India
# url :  None
# created date =  2019-08-29 17:35:00
# 288 days, 10:00:16.890711
# Account age (in days): 288
# False
# followers data is  [1167128409085890560, '1167128409085890560', 'VenkadeshK10', 'Tirunelveli,TamilNadu,India', '', None, 5, 13, 0, datetime.datetime(2019, 8, 29, 17, 35), 0, False, 0, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Sat Dec 14 08:00:27 +0000 2019\', \'id\': 1205759440806244352, \'id_str\': \'1205759440806244352\', \'text\': \'RT @sachin_rt: எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\\n\\nசென்னை டெஸ்ட் தொடரின் போது \\nTaj Coromandel ஊழியர் ஒரு…\', \'truncated\': False, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'sachin_rt\', \'name\': \'Sachin Tendulkar\', \'id\': 135421739, \'id_str\': \'135421739\', \'indices\': [3, 13]}], \'urls\': []}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'retweeted_status\': {\'created_at\': \'Sat Dec 14 07:57:54 +0000 2019\', \'id\': 1205758801334296577, \'id_str\': \'1205758801334296577\', \'text\': \'எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\\n\\nசென்னை டெஸ்ட் தொடரின் போது \\nTaj Coromandel ஊ… https://t.co/L0O4rfLxMO\', \'truncated\': True, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/L0O4rfLxMO\', \'expanded_url\': \'https://twitter.com/i/web/status/1205758801334296577\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, \'source\': \'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>\', \'in_reply_to_status_id\': 1205757235407671296, \'in_reply_to_status_id_str\': \'1205757235407671296\', \'in_reply_to_user_id\': 135421739, \'in_reply_to_user_id_str\': \'135421739\', \'in_reply_to_screen_name\': \'sachin_rt\', \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 4950, \'favorite_count\': 18660, \'favorited\': False, \'retweeted\': False, \'lang\': \'ta\'}, \'is_quote_status\': False, \'retweet_count\': 4950, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'ta\'}, created_at=datetime.datetime(2019, 12, 14, 8, 0, 27), id=1205759440806244352, id_str=\'1205759440806244352\', text=\'RT @sachin_rt: எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\\n\\nசென்னை டெஸ்ட் தொடரின் போது \\nTaj Coromandel ஊழியர் ஒரு…\', truncated=False, entities={\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'sachin_rt\', \'name\': \'Sachin Tendulkar\', \'id\': 135421739, \'id_str\': \'135421739\', \'indices\': [3, 13]}], \'urls\': []}, source=\'Twitter for Android\', source_url=\'http://twitter.com/download/android\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, retweeted_status=Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Sat Dec 14 07:57:54 +0000 2019\', \'id\': 1205758801334296577, \'id_str\': \'1205758801334296577\', \'text\': \'எதிர்பாராத சந்திப்புகள் சில சமயம் மறக்க முடியாத தருணங்களாக மாறுகின்றன\\n\\nசென்னை டெஸ்ட் தொடரின் போது \\nTaj Coromandel ஊ… https://t.co/L0O4rfLxMO\', \'truncated\': True, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/L0O4rfLxMO\', \'expanded_url\': \'https://twitter.com/i/web/status/1205758801334296577\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, \'source\': \'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>\', \'in_reply_to_status_id\': 120 ...
#
#
# user_id is  1142386746694332416
# name: Santhosh Kumar
# screen_name: SantyKumaru
# description:
# statuses_count:  2
# friends_count:  12
# followers_count:  1
# favourites count: 2
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Thu Feb 27 00:22:39 +0000 2020', 'id': 1232823322431254528, 'id_str': '1232823322431254528', 'text': "I found a #cloud #torrent that's awesome ;) @seedrcoil it's FREE just give it a try! https://t.co/oHUwdA3WqO", 'truncated': False, 'entities': {'hashtags': [{'text': 'cloud', 'indices': [10, 16]}, {'text': 'torrent', 'indices': [17, 25]}], 'symbols': [], 'user_mentions': [{'screen_name': 'seedrcoil', 'name': 'Seedr Official', 'id': 2582437764, 'id_str': '2582437764', 'indices': [44, 54]}], 'urls': [{'url': 'https://t.co/oHUwdA3WqO', 'expanded_url': 'https://www.seedr.cc/', 'display_url': 'seedr.cc', 'indices': [85, 108]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 2, 27, 0, 22, 39), id=1232823322431254528, id_str='1232823322431254528', text="I found a #cloud #torrent that's awesome ;) @seedrcoil it's FREE just give it a try! https://t.co/oHUwdA3WqO", truncated=False, entities={'hashtags': [{'text': 'cloud', 'indices': [10, 16]}, {'text': 'torrent', 'indices': [17, 25]}], 'symbols': [], 'user_mentions': [{'screen_name': 'seedrcoil', 'name': 'Seedr Official', 'id': 2582437764, 'id_str': '2582437764', 'indices': [44, 54]}], 'urls': [{'url': 'https://t.co/oHUwdA3WqO', 'expanded_url': 'https://www.seedr.cc/', 'display_url': 'seedr.cc', 'indices': [85, 108]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, possibly_sensitive=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  True
# has extended profile:  False
# id : 1142386746694332416
# id_str : 1142386746694332416
# location :
# url :  None
# created date =  2019-06-22 10:59:59
# 356 days, 16:35:18.443928
# Account age (in days): 356
# False
# followers data is  [1142386746694332416, '1142386746694332416', 'SantyKumaru', '', '', None, 1, 12, 0, datetime.datetime(2019, 6, 22, 10, 59, 59), 2, False, 2, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Thu Feb 27 00:22:39 +0000 2020\', \'id\': 1232823322431254528, \'id_str\': \'1232823322431254528\', \'text\': "I found a #cloud #torrent that\'s awesome ;) @seedrcoil it\'s FREE just give it a try! https://t.co/oHUwdA3WqO", \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'cloud\', \'indices\': [10, 16]}, {\'text\': \'torrent\', \'indices\': [17, 25]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'seedrcoil\', \'name\': \'Seedr Official\', \'id\': 2582437764, \'id_str\': \'2582437764\', \'indices\': [44, 54]}], \'urls\': [{\'url\': \'https://t.co/oHUwdA3WqO\', \'expanded_url\': \'https://www.seedr.cc/\', \'display_url\': \'seedr.cc\', \'indices\': [85, 108]}]}, \'source\': \'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'possibly_sensitive\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2020, 2, 27, 0, 22, 39), id=1232823322431254528, id_str=\'1232823322431254528\', text="I found a #cloud #torrent that\'s awesome ;) @seedrcoil it\'s FREE just give it a try! https://t.co/oHUwdA3WqO", truncated=False, entities={\'hashtags\': [{\'text\': \'cloud\', \'indices\': [10, 16]}, {\'text\': \'torrent\', \'indices\': [17, 25]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'seedrcoil\', \'name\': \'Seedr Official\', \'id\': 2582437764, \'id_str\': \'2582437764\', \'indices\': [44, 54]}], \'urls\': [{\'url\': \'https://t.co/oHUwdA3WqO\', \'expanded_url\': \'https://www.seedr.cc/\', \'display_url\': \'seedr.cc\', \'indices\': [85, 108]}]}, source=\'Twitter Web Client\', source_url=\'http://twitter.com\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, possibly_sensitive=False, lang=\'en\')', 'True', 'True', 'False', 'Santhosh Kumar']
#
#
# user_id is  273423046
# name: Urban Tree Homes
# screen_name: urbantreehomes
# description: Real estate & property builder with budget housing at Porur, Vanagaram, Urapakkam, Thiruvanmiyur, Perumbakkam & more!
# statuses_count:  9509
# friends_count:  2691
# followers_count:  2194
# favourites count: 1863
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Wed Oct 02 12:30:33 +0000 2019', 'id': 1179373099747291138, 'id_str': '1179373099747291138', 'text': 'Nothing is better than going home to family and eating good food and relaxing. Get a peaceful #home to relax at… https://t.co/j9lP5oHhng', 'truncated': True, 'entities': {'hashtags': [{'text': 'home', 'indices': [94, 99]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/j9lP5oHhng', 'expanded_url': 'https://twitter.com/i/web/status/1179373099747291138', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [113, 136]}]}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 10, 2, 12, 30, 33), id=1179373099747291138, id_str='1179373099747291138', text='Nothing is better than going home to family and eating good food and relaxing. Get a peaceful #home to relax at… https://t.co/j9lP5oHhng', truncated=True, entities={'hashtags': [{'text': 'home', 'indices': [94, 99]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/j9lP5oHhng', 'expanded_url': 'https://twitter.com/i/web/status/1179373099747291138', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [113, 136]}]}, source='Hootsuite Inc.', source_url='https://www.hootsuite.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang='en')
# listed count:  95
# default_profile:  False
# default_image:  False
# has extended profile:  False
# id : 273423046
# id_str : 273423046
# location : Chennai
# url :  https://t.co/AaAfyEzq5B
# created date =  2011-03-28 13:25:32
# 3364 days, 14:09:45.952899
# Account age (in days): 3364
# False
# followers data is  [273423046, '273423046', 'urbantreehomes', 'Chennai', 'Real estate & property builder with budget housing at Porur, Vanagaram, Urapakkam, Thiruvanmiyur, Perumbakkam & more!', 'https://t.co/AaAfyEzq5B', 2194, 2691, 95, datetime.datetime(2011, 3, 28, 13, 25, 32), 1863, False, 9509, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Wed Oct 02 12:30:33 +0000 2019\', \'id\': 1179373099747291138, \'id_str\': \'1179373099747291138\', \'text\': \'Nothing is better than going home to family and eating good food and relaxing. Get a peaceful #home to relax at… https://t.co/j9lP5oHhng\', \'truncated\': True, \'entities\': {\'hashtags\': [{\'text\': \'home\', \'indices\': [94, 99]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/j9lP5oHhng\', \'expanded_url\': \'https://twitter.com/i/web/status/1179373099747291138\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [113, 136]}]}, \'source\': \'<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2019, 10, 2, 12, 30, 33), id=1179373099747291138, id_str=\'1179373099747291138\', text=\'Nothing is better than going home to family and eating good food and relaxing. Get a peaceful #home to relax at… https://t.co/j9lP5oHhng\', truncated=True, entities={\'hashtags\': [{\'text\': \'home\', \'indices\': [94, 99]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/j9lP5oHhng\', \'expanded_url\': \'https://twitter.com/i/web/status/1179373099747291138\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [113, 136]}]}, source=\'Hootsuite Inc.\', source_url=\'https://www.hootsuite.com\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang=\'en\')', 'False', 'False', 'False', 'Urban Tree Homes']
#
#
# user_id is  1047311216937508864
# name: Willing Go
# screen_name: Willinggo_Cn
# description: Willing Go is a #Sourcing #Specialists #services provider based in #China, we served 1000- satisfied #customer with #High_quality since 2010 #trust #USA 🇺🇸 🇨🇳
# statuses_count:  1655
# friends_count:  2614
# followers_count:  786
# favourites count: 11133
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Thu May 30 05:46:51 +0000 2019', 'id': 1133973023265083393, 'id_str': '1133973023265083393', 'text': 'our 2019 collection is amazing!! place your order today and start sourcing from China\n- 925 sterling silver\n- Adjus… https://t.co/0kAyzDYE0a', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/0kAyzDYE0a', 'expanded_url': 'https://twitter.com/i/web/status/1133973023265083393', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 5, 30, 5, 46, 51), id=1133973023265083393, id_str='1133973023265083393', text='our 2019 collection is amazing!! place your order today and start sourcing from China\n- 925 sterling silver\n- Adjus… https://t.co/0kAyzDYE0a', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/0kAyzDYE0a', 'expanded_url': 'https://twitter.com/i/web/status/1133973023265083393', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=2, favorited=False, retweeted=False, possibly_sensitive=False, lang='en')
# listed count:  2
# default_profile:  False
# default_image:  False
# has extended profile:  True
# id : 1047311216937508864
# id_str : 1047311216937508864
# location : shenzhen, China
# url :  https://t.co/HPoyGZJvTR
# created date =  2018-10-03 02:23:47
# 619 days, 1:11:31.419187
# Account age (in days): 619
# False
# followers data is  [1047311216937508864, '1047311216937508864', 'Willinggo_Cn', 'shenzhen, China', 'Willing Go is a #Sourcing #Specialists #services provider based in #China, we served 1000- satisfied #customer with #High_quality since 2010 #trust #USA 🇺🇸 🇨🇳', 'https://t.co/HPoyGZJvTR', 786, 2614, 2, datetime.datetime(2018, 10, 3, 2, 23, 47), 11133, False, 1655, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Thu May 30 05:46:51 +0000 2019\', \'id\': 1133973023265083393, \'id_str\': \'1133973023265083393\', \'text\': \'our 2019 collection is amazing!! place your order today and start sourcing from China\\n- 925 sterling silver\\n- Adjus… https://t.co/0kAyzDYE0a\', \'truncated\': True, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/0kAyzDYE0a\', \'expanded_url\': \'https://twitter.com/i/web/status/1133973023265083393\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, \'source\': \'<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 2, \'favorited\': False, \'retweeted\': False, \'possibly_sensitive\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2019, 5, 30, 5, 46, 51), id=1133973023265083393, id_str=\'1133973023265083393\', text=\'our 2019 collection is amazing!! place your order today and start sourcing from China\\n- 925 sterling silver\\n- Adjus… https://t.co/0kAyzDYE0a\', truncated=True, entities={\'hashtags\': [], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/0kAyzDYE0a\', \'expanded_url\': \'https://twitter.com/i/web/status/1133973023265083393\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, source=\'Twitter Web App\', source_url=\'https://mobile.twitter.com\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=2, favorited=False, retweeted=False, possibly_sensitive=False, lang=\'en\')', 'False', 'False', 'True', 'Willing Go']
#
#
# user_id is  1084446431987957761
# name: Mr.Black_Pearl
# screen_name: RamVasa28926875
# description: 1st cried 'June 17'😘
# Honda CB Hornet 160R Rider 😍😍
# No Matter How Bad Your Day Is
# Your Bike Will Always
# Make You Feel Better😎😎
# Single✌💪
# Mech da 🔧
# statuses_count:  1
# friends_count:  198
# followers_count:  11
# favourites count: 4
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Thu May 09 11:27:40 +0000 2019', 'id': 1126448645979590656, 'id_str': '1126448645979590656', 'text': '@KollywudCinema 19', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Kollywudcinema', 'name': 'Bigil', 'id': 1148541540660178944, 'id_str': '1148541540660178944', 'indices': [0, 15]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1125628613494050816, 'in_reply_to_status_id_str': '1125628613494050816', 'in_reply_to_user_id': 346379998, 'in_reply_to_user_id_str': '346379998', 'in_reply_to_screen_name': 'KollywoodCinima', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'und'}, created_at=datetime.datetime(2019, 5, 9, 11, 27, 40), id=1126448645979590656, id_str='1126448645979590656', text='@KollywudCinema 19', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Kollywudcinema', 'name': 'Bigil', 'id': 1148541540660178944, 'id_str': '1148541540660178944', 'indices': [0, 15]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1125628613494050816, in_reply_to_status_id_str='1125628613494050816', in_reply_to_user_id=346379998, in_reply_to_user_id_str='346379998', in_reply_to_screen_name='KollywoodCinima', geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang='und')
# listed count:  0
# default_profile:  True
# default_image:  False
# has extended profile:  True
# id : 1084446431987957761
# id_str : 1084446431987957761
# location : Thanjavur, India
# url :  None
# created date =  2019-01-13 13:45:52
# 516 days, 13:49:26.971073
# Account age (in days): 516
# False
# followers data is  [1084446431987957761, '1084446431987957761', 'RamVasa28926875', 'Thanjavur, India', "1st cried 'June 17'😘\nHonda CB Hornet 160R Rider 😍😍\nNo Matter How Bad Your Day Is\nYour Bike Will Always\nMake You Feel Better😎😎\nSingle✌💪\nMech da 🔧", None, 11, 198, 0, datetime.datetime(2019, 1, 13, 13, 45, 52), 4, False, 1, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Thu May 09 11:27:40 +0000 2019\', \'id\': 1126448645979590656, \'id_str\': \'1126448645979590656\', \'text\': \'@KollywudCinema 19\', \'truncated\': False, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'Kollywudcinema\', \'name\': \'Bigil\', \'id\': 1148541540660178944, \'id_str\': \'1148541540660178944\', \'indices\': [0, 15]}], \'urls\': []}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': 1125628613494050816, \'in_reply_to_status_id_str\': \'1125628613494050816\', \'in_reply_to_user_id\': 346379998, \'in_reply_to_user_id_str\': \'346379998\', \'in_reply_to_screen_name\': \'KollywoodCinima\', \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'und\'}, created_at=datetime.datetime(2019, 5, 9, 11, 27, 40), id=1126448645979590656, id_str=\'1126448645979590656\', text=\'@KollywudCinema 19\', truncated=False, entities={\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'Kollywudcinema\', \'name\': \'Bigil\', \'id\': 1148541540660178944, \'id_str\': \'1148541540660178944\', \'indices\': [0, 15]}], \'urls\': []}, source=\'Twitter for Android\', source_url=\'http://twitter.com/download/android\', in_reply_to_status_id=1125628613494050816, in_reply_to_status_id_str=\'1125628613494050816\', in_reply_to_user_id=346379998, in_reply_to_user_id_str=\'346379998\', in_reply_to_screen_name=\'KollywoodCinima\', geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang=\'und\')', 'True', 'False', 'True', 'Mr.Black_Pearl']
#
#
# user_id is  739090111338401792
# name: Dhanagodeswaran
# screen_name: dhanagodes19
# description: Student...
# statuses_count:  36
# friends_count:  55
# ...
#
#
# user_id is  2409048883
# name: Arvindchezian
# screen_name: arvindchezian
# description: ....
# statuses_count:  0
# friends_count:  346
# followers_count:  22
# favourites count: 2
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Tue Feb 11 16:29:32 +0000 2020', 'id': 1227268440978669573, 'id_str': '1227268440978669573', 'text': '#Master #OruKuttiKadhai @Dir_Lokesh @actorvijay @anirudhofficial @VijaySethuOffl https://t.co/i7FIxDenEq', 'truncated': False, 'entities': {'hashtags': [{'text': 'Master', 'indices': [0, 7]}, {'text': 'OruKuttiKadhai', 'indices': [8, 23]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Dir_Lokesh', 'name': 'Lokesh Kanagaraj', 'id': 1103860407624556546, 'id_str': '1103860407624556546', 'indices': [24, 35]}, {'screen_name': 'actorvijay', 'name': 'Vijay', 'id': 1156338067, 'id_str': '1156338067', 'indices': [36, 47]}, {'screen_name': 'anirudhofficial', 'name': 'Anirudh Ravichander', 'id': 216447259, 'id_str': '216447259', 'indices': [48, 64]}, {'screen_name': 'VijaySethuOffl', 'name': 'VijaySethupathi', 'id': 1002079927292772354, 'id_str': '1002079927292772354', 'indices': [65, 80]}], 'urls': [], 'media': [{'id': 1227268416496492544, 'id_str': '1227268416496492544', 'indices': [81, 104], 'media_url': 'http://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg', 'url': 'https://t.co/i7FIxDenEq', 'display_url': 'pic.twitter.com/i7FIxDenEq', 'expanded_url': 'https://twitter.com/VasanthRam17/status/1227268440978669573/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 2048, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1227268416496492544, 'id_str': '1227268416496492544', 'indices': [81, 104], 'media_url': 'http://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg', 'url': 'https://t.co/i7FIxDenEq', 'display_url': 'pic.twitter.com/i7FIxDenEq', 'expanded_url': 'https://twitter.com/VasanthRam17/status/1227268440978669573/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 2048, 'resize': 'fit'}}}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 3, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'und'}, created_at=datetime.datetime(2020, 2, 11, 16, 29, 32), id=1227268440978669573, id_str='1227268440978669573', text='#Master #OruKuttiKadhai @Dir_Lokesh @actorvijay @anirudhofficial @VijaySethuOffl https://t.co/i7FIxDenEq', truncated=False, entities={'hashtags': [{'text': 'Master', 'indices': [0, 7]}, {'text': 'OruKuttiKadhai', 'indices': [8, 23]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Dir_Lokesh', 'name': 'Lokesh Kanagaraj', 'id': 1103860407624556546, 'id_str': '1103860407624556546', 'indices': [24, 35]}, {'screen_name': 'actorvijay', 'name': 'Vijay', 'id': 1156338067, 'id_str': '1156338067', 'indices': [36, 47]}, {'screen_name': 'anirudhofficial', 'name': 'Anirudh Ravichander', 'id': 216447259, 'id_str': '216447259', 'indices': [48, 64]}, {'screen_name': 'VijaySethuOffl', 'name': 'VijaySethupathi', 'id': 1002079927292772354, 'id_str': '1002079927292772354', 'indices': [65, 80]}], 'urls': [], 'media': [{'id': 1227268416496492544, 'id_str': '1227268416496492544', 'indices': [81, 104], 'media_url': 'http://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg', 'url': 'https://t.co/i7FIxDenEq', 'display_url': 'pic.twitter.com/i7FIxDenEq', 'expanded_url': 'https://twitt ...
# listed count:  0
# default_profile:  True
# default_image:  False
# has extended profile:  True
# id : 2409048883
# id_str : 2409048883
# location :
# url :  None
# created date =  2014-03-24 13:49:42
# 2272 days, 13:45:50.286043
# Account age (in days): 2272
# False
# followers data is  [2409048883, '2409048883', 'arvindchezian', '', '....', None, 22, 346, 0, datetime.datetime(2014, 3, 24, 13, 49, 42), 2, False, 0, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Tue Feb 11 16:29:32 +0000 2020\', \'id\': 1227268440978669573, \'id_str\': \'1227268440978669573\', \'text\': \'#Master #OruKuttiKadhai @Dir_Lokesh @actorvijay @anirudhofficial @VijaySethuOffl https://t.co/i7FIxDenEq\', \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'Master\', \'indices\': [0, 7]}, {\'text\': \'OruKuttiKadhai\', \'indices\': [8, 23]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'Dir_Lokesh\', \'name\': \'Lokesh Kanagaraj\', \'id\': 1103860407624556546, \'id_str\': \'1103860407624556546\', \'indices\': [24, 35]}, {\'screen_name\': \'actorvijay\', \'name\': \'Vijay\', \'id\': 1156338067, \'id_str\': \'1156338067\', \'indices\': [36, 47]}, {\'screen_name\': \'anirudhofficial\', \'name\': \'Anirudh Ravichander\', \'id\': 216447259, \'id_str\': \'216447259\', \'indices\': [48, 64]}, {\'screen_name\': \'VijaySethuOffl\', \'name\': \'VijaySethupathi\', \'id\': 1002079927292772354, \'id_str\': \'1002079927292772354\', \'indices\': [65, 80]}], \'urls\': [], \'media\': [{\'id\': 1227268416496492544, \'id_str\': \'1227268416496492544\', \'indices\': [81, 104], \'media_url\': \'http://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg\', \'media_url_https\': \'https://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg\', \'url\': \'https://t.co/i7FIxDenEq\', \'display_url\': \'pic.twitter.com/i7FIxDenEq\', \'expanded_url\': \'https://twitter.com/VasanthRam17/status/1227268440978669573/photo/1\', \'type\': \'photo\', \'sizes\': {\'small\': {\'w\': 680, \'h\': 680, \'resize\': \'fit\'}, \'thumb\': {\'w\': 150, \'h\': 150, \'resize\': \'crop\'}, \'medium\': {\'w\': 1200, \'h\': 1200, \'resize\': \'fit\'}, \'large\': {\'w\': 2048, \'h\': 2048, \'resize\': \'fit\'}}}]}, \'extended_entities\': {\'media\': [{\'id\': 1227268416496492544, \'id_str\': \'1227268416496492544\', \'indices\': [81, 104], \'media_url\': \'http://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg\', \'media_url_https\': \'https://pbs.twimg.com/media/EQgiH1lUYAAQ5K0.jpg\', \'url\': \'https://t.co/i7FIxDenEq\', \'display_url\': \'pic.twitter.com/i7FIxDenEq\', \'expanded_url\': \'https://twitter.com/VasanthRam17/status/1227268440978669573/photo/1\', \'type\': \'photo\', \'sizes\': {\'small\': {\'w\': 680, \'h\': 680, \'resize\': \'fit\'}, \'thumb\': {\'w\': 150, \'h\': 150, \'resize\': \'crop\'}, \'medium\': {\'w\': 1200, \'h\': 1200, \'resize\': \'fit\'}, \'large\': {\'w\': 2048, \'h\': 2048, \'resize\': \'fit\'}}}]}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 3, \'favorited\': False, \'retweeted\': False, \'possibly_sensitive\': False, \'lang\': \'und\'}, created_at=datetime.datetime(2020, 2, 11, 16, 29, 32), id=1227268440978669573, id_str=\'1227268440978669573\', text=\'#Master #OruKuttiKadhai @Dir_Lokesh @actorvijay @anirudhofficial @VijaySethuOffl https://t.co/i7FIxDenEq\', truncated=False, entities={\'hashtags\': [{\'text\': \'Master\', \'indices\': [0, 7]}, {\'text\': \'OruKuttiKadhai\', \'indices\': [8, 23]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'Dir_Lokesh\', \'name\': \'Lokesh Kanagaraj\', \'id\': 1103860407624556546, \'id_str\': \'1103860407624556546\', \'indices\': [24, 35]}, {\'screen_name\': \'actorvijay\', \'name\': \'Vijay\', \'id\': 1156338067, \'id_str\': \'1156338067\', \'indices\': [36, 47]}, {\'screen_name\': \'anirudhofficial\', \'name\': \'Anirudh Ravichander\', \'id\': 216447259, \'id_str\': \'216447259\', \'i ...
#
#
# user_id is  752528322270081024
# name: Venk@ Ragavan
# screen_name: venkynuja
# description:
# statuses_count:  15
# friends_count:  55
# followers_count:  10
# favourites count: 8
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={'created_at': 'Tue Nov 13 17:48:18 +0000 2018', 'id': 1062401783778160640, 'id_str': '1062401783778160640', 'text': 'The thing we often like to do✨💖\nOne rough video.😅\n#imaikanodigal #favsong\n#hiphopadhi#hobbythings https://t.co/pHkAfnoFaM', 'truncated': False, 'entities': {'hashtags': [{'text': 'imaikanodigal', 'indices': [50, 64]}, {'text': 'favsong', 'indices': [65, 73]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/pHkAfnoFaM', 'expanded_url': 'https://www.instagram.com/p/BqIPXDMDfy8/?utm_source=ig_twitter_share&igshid=11qlwtn8e0fb6', 'display_url': 'instagram.com/p/BqIPXDMDfy8/…', 'indices': [98, 121]}]}, 'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 11, 13, 17, 48, 18), id=1062401783778160640, id_str='1062401783778160640', text='The thing we often like to do✨💖\nOne rough video.😅\n#imaikanodigal #favsong\n#hiphopadhi#hobbythings https://t.co/pHkAfnoFaM', truncated=False, entities={'hashtags': [{'text': 'imaikanodigal', 'indices': [50, 64]}, {'text': 'favsong', 'indices': [65, 73]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/pHkAfnoFaM', 'expanded_url': 'https://www.instagram.com/p/BqIPXDMDfy8/?utm_source=ig_twitter_share&igshid=11qlwtn8e0fb6', 'display_url': 'instagram.com/p/BqIPXDMDfy8/…', 'indices': [98, 121]}]}, source='Instagram', source_url='http://instagram.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, possibly_sensitive=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  True
# has extended profile:  True
# id : 752528322270081024
# id_str : 752528322270081024
# location :
# url :  None
# created date =  2016-07-11 15:41:48
# 1432 days, 11:53:44.777181
# Account age (in days): 1432
# False
# followers data is  [752528322270081024, '752528322270081024', 'venkynuja', '', '', None, 10, 55, 0, datetime.datetime(2016, 7, 11, 15, 41, 48), 8, False, 15, None, 'Status(_api=<tweepy.api.API object at 0x00000202CE022DC8>, _json={\'created_at\': \'Tue Nov 13 17:48:18 +0000 2018\', \'id\': 1062401783778160640, \'id_str\': \'1062401783778160640\', \'text\': \'The thing we often like to do✨💖\\nOne rough video.😅\\n#imaikanodigal #favsong\\n#hiphopadhi#hobbythings https://t.co/pHkAfnoFaM\', \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'imaikanodigal\', \'indices\': [50, 64]}, {\'text\': \'favsong\', \'indices\': [65, 73]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/pHkAfnoFaM\', \'expanded_url\': \'https://www.instagram.com/p/BqIPXDMDfy8/?utm_source=ig_twitter_share&igshid=11qlwtn8e0fb6\', \'display_url\': \'instagram.com/p/BqIPXDMDfy8/…\', \'indices\': [98, 121]}]}, \'source\': \'<a href="http://instagram.com" rel="nofollow">Instagram</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'possibly_sensitive\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2018, 11, 13, 17, 48, 18), id=1062401783778160640, id_str=\'1062401783778160640\', text=\'The thing we often like to do✨💖\\nOne rough video.😅\\n#imaikanodigal #favsong\\n#hiphopadhi#hobbythings https://t.co/pHkAfnoFaM\', truncated=False, entities={\'hashtags\': [{\'text\': \'imaikanodigal\', \'indices\': [50, 64]}, {\'text\': \'favsong\', \'indices\': [65, 73]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/pHkAfnoFaM\', \'expanded_url\': \'https://www.instagram.com/p/BqIPXDMDfy8/?utm_source=ig_twitter_share&igshid=11qlwtn8e0fb6\', \'display_url\': \'instagram.com/p/BqIPXDMDfy8/…\', \'indices\': [98, 121]}]}, source=\'Instagram\', source_url=\'http://instagram.com\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, possibly_sensitive=False, lang=\'en\')', 'True', 'True', 'True', 'Venk@ Ragavan']

# %%
#print(final)
followers_df=pd.DataFrame(final,columns=['id','id_str','screen_name','location','description','url','followers_count','friends_count','listed_count','created_at','favourites_count','verified','statuses_count','lang','status','default_profile','default_profile_image','has_extended_profile','name'])
followers_df['bot']=''
print(followers_df.tail())
# Out:
#                     id              id_str      screen_name    location  \
# 29  756102342924046336  756102342924046336   Ramana18113114
# 30  740865625233334272  740865625233334272  Sathish43161392
# 31  757531961426489344  757531961426489344     VasanthRam17  Thanjavur
# 32          2409048883          2409048883    arvindchezian
# 33  752528322270081024  752528322270081024        venkynuja
#
#                                           description   url  followers_count  \
# 29                                                     None               18
# 30                                                     None               23
# 31  Honda CB Hornet 160R Rider 😍😍\nNo Matter How B...  None               36
# 32                                               ....  None               22
# 33                                                     None               10
#
#     friends_count  listed_count          created_at  favourites_count  \
# 29             45             0 2016-07-21 12:23:41                 3
# 30             76             0 2016-06-09 11:18:24                 0
# 31            468             0 2016-07-25 11:04:28              1400
# 32            346             0 2014-03-24 13:49:42                 2
# 33             55             0 2016-07-11 15:41:48                 8
#
#     verified  statuses_count  lang  \
# 29     False               0  None
# 30     False               1  None
# 31     False              27  None
# 32     False               0  None
# 33     False              15  None
#
#                                                status default_profile  \
# 29  Status(_api=<tweepy.api.API object at 0x000002...            True
# 30  Status(_api=<tweepy.api.API object at 0x000002...            True
# 31  Status(_api=<tweepy.api.API object at 0x000002...            True
# 32  Status(_api=<tweepy.api.API object at 0x000002...            True
# 33  Status(_api=<tweepy.api.API object at 0x000002...            True
#
#    default_profile_image has_extended_profile           name bot
# 29                 False                 True         Ramana
# 30                 False                False        Sathish
# 31                 False                 True  mr.p_s_y_c_h_
# 32                 False                 True  Arvindchezian
# 33                  True                 True  Venk@ Ragavan
