# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import string
import nltk
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
# Out:
# Getting data for @UdhayavannanUvi
# name: A.Udhayavannan
# screen_name: UdhayavannanUvi
# description:
# statuses_count: 48
# friends_count: 108
# followers_count: 35
# created date =  2016-07-17 06:55:18
# 1336 days, 11:36:24.357587
# Account age (in days): 1336
# Average tweets per day: 0.04
# tweet count 48
#
# 47
# 82
#
# Most used hashtags:
# AvengersEndgame	2
# RiseofSkywalker	1
# CHEvsJAI	1
# vivoProKabaddi	1
# IsseToughKuchNahi	1
# ironman	1
# captainamerica	1
# Whateverittakes	1
# SPICinemas	1
# endgame	1
# reputation =  0.2447552448
# mentions raitio =  1.7083333333
# hashtag_ratio = 0.2708333333
# unique mentions = 0.5731707317
# All done. Processed 48 tweets.
# 2019-10-24 05:34:47
# 0
# 2019-10-24 04:37:42
# 0
# 2019-08-21 16:23:05
# 0
# 2019-07-10 14:21:34
# 0
# 2019-05-28 04:07:27
# 0
# 2019-05-27 03:29:58
# 0
# 2019-05-27 03:24:59
# 0
# 2019-04-25 14:51:13
# 0
# 2019-04-24 01:27:16
# 0
# 2019-04-23 15:59:15
# 0
# 2019-04-23 15:58:48
# 0
# 2019-04-23 15:58:40
# 0
# 2019-04-23 15:58:21
# 0
# 2019-04-23 15:58:07
# 0
# 2019-04-23 15:57:59
# 0
# 2019-04-23 15:57:52
# 0
# 2019-04-23 15:57:46
# 0
# 2019-04-23 15:57:38
# 0
# 2019-04-23 15:57:30
# 0
# 2019-04-23 15:57:21
# 0
# 2019-04-23 15:57:08
# 0
# 2019-04-23 15:56:54
# 0
# 2019-04-23 15:56:48
# 0
# 2019-04-23 15:56:19
# 0
# 2019-04-23 15:55:44
# 0
# 2019-04-23 15:55:28
# 0
# 2019-04-23 15:55:18
# 0
# 2019-04-23 15:55:07
# 0
# 2019-04-23 15:54:57
# 0
# 2019-04-23 15:54:48
# 0
# 2019-04-23 15:54:39
# 0
# 2019-04-23 15:54:30
# 0
# 2019-04-23 15:54:21
# 0
# 2019-04-23 15:54:10
# 0
# 2019-04-23 15:53:52
# 0
# 2019-04-23 15:53:43
# 0
# 2019-04-23 15:53:36
# 0
# 2019-04-23 15:53:26
# 0
# 2019-04-23 15:53:14
# 0
# 2019-04-23 15:53:02
# 0
# 2019-04-23 12:54:42
# 0
# 2019-04-23 11:54:02
# 0
# 2019-04-23 11:45:08
# 0
# 2019-04-23 06:56:27
# 0
# 2019-04-22 15:34:29
# 0
# 2019-04-22 15:02:05
# 0
# 2019-04-19 00:44:04
# 0
# 2019-03-14 16:20:37
# 0
# total intertweet_delay 219
# mean_of_intertweet_delay  4.5625
# sd of intertweet delay  18.3772320073
# avg_tweets day and week 0.0359281437   0.251497006
# twitter urls :
# url posted by user:
# https://t.co/LtkO3psEBX
# twitter urls :
# https://t.co/HRh0zlKv3S
# {'hashtags': [{'text': 'Whateverittakes', 'indices': [11, 27]}, {'text': 'AvengersEndgame', 'indices': [40, 56]}], 'symbols': [], 'user_mentions': [{'screen_name': 'GKcinemas', 'name': 'Ruban Mathivanan', 'id': 128495725, 'id_str': '128495725', 'indices': [0, 10]}], 'urls': [{'url': 'https://t.co/HRh0zlKv3S', 'expanded_url': 'https://twitter.com/i/web/status/1120657078115164162', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}
#
#
# twitter urls :
# https://t.co/2ZK0rvycom
# {'hashtags': [{'text': 'Thor', 'indices': [57, 62]}, {'text': 'Loki', 'indices': [94, 99]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ForumVijayaMall', 'name': 'TheForumVijayaMall', 'id': 1006089008, 'id_str': '1006089008', 'indices': [0, 16]}, {'screen_name': 'SPICinemas', 'name': 'SPI Cinemas', 'id': 919079586, 'id_str': '919079586', 'indices': [17, 28]}], 'urls': [{'url': 'https://t.co/2ZK0rvycom', 'expanded_url': 'https://twitter.com/i/web/status/1120350168258187264', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [101, 124]}]}
#
#
# twitter urls :
# https://t.co/9culWXKUHO
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'NASA', 'name': 'NASA', 'id': 11348282, 'id_str': '11348282', 'indices': [8, 13]}, {'screen_name': 'Iron_Man', 'name': 'Iron Man', 'id': 570218986, 'id_str': '570218986', 'indices': [32, 41]}, {'screen_name': 'Avengers', 'name': 'The Avengers', 'id': 393852070, 'id_str': '393852070', 'indices': [71, 80]}], 'urls': [{'url': 'https://t.co/9culWXKUHO', 'expanded_url': 'https://twitter.com/i/web/status/1106228648732819457', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}
#
#
# url count is  1
# url ratio is  0.0208333333
# retweet rate is  0.0
# No_PlasticWaste
# None
# JaipurPanthers
# _PVRCinemas
# None
# None
# None
# None
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# VettriTheatres
# GKcinemas
# SPICinemas
# GKcinemas
# ForumVijayaMall
# massguna06gmai1
# GoogleStadia
# None
# reply rate is  0.875
# Getting data for @UdhayavannanUvi
# False
# 0
#
#                                                  Tweet
# 0          @No_PlasticWaste @minderoo @TEDchris hello
# 1           #RiseofSkywalker  https://t.co/LtkO3psEBX
# 2   @JaipurPanthers Even the commentary says. But ...
# 3                                   @_PVRCinemas puli
# 4    @CarnivalCine movie release date  30 or 31 ?????
# 5   @CarnivalCine Godzilla movie Evp la viduvingal...
# 6   @CarnivalCine When will you release the ticket...
# 7   @CarnivalCine #ironman dies and #captainameric...
# 8   @SPICinemas @hackiz @vrlokesh1992 i dont need ...
# 9          @SPICinemas @BagathSanju Enough already n8
# 10                     @SPICinemas @sbk585 already n8
# 11            @SPICinemas @bnikhileshwarre already n8
# 12              @SPICinemas @fosterjack631 already n8
# 13              @SPICinemas @gokulrock1702 already n8
# 14            @SPICinemas @SudarshanSivak1 already n8
# 15              @SPICinemas @gokul60699263 already n8
# 16                @SPICinemas @KrizzArvind already n8
# 17                 @SPICinemas @rafi200331 already n8
# 18            @SPICinemas @SanjayC91429472 already n8
# 19              @SPICinemas @Surya83740256 already n8
# 20                    @SPICinemas @Rogshii already n8
# 21            @SPICinemas @Yashwan48643397 already n8
# 22  @SPICinemas @PrakashKathir7 @TheCinemabySPI al...
# 23   @SPICinemas @saravana_assr In Chennai already n8
# 24             @SPICinemas @S__ViNoDhKuMaR already n8
# 25            @SPICinemas @IlayaBharathi14 already n8
# 26                  @SPICinemas @raaghul06 already n8
# 27            @SPICinemas @Anbulogachandr1 already n8
# 28               @SPICinemas @tarun_aadith already n8
# 29                  @SPICinemas @arif_1305 already n8
# 30                  @SPICinemas @Bheembwoy already n8
# 31                @SPICinemas @AkashAk2812 already n8
# 32                @SPICinemas @siddhubalaj already n8
# 33                 @SPICinemas @Havinash20 already n8
# 34                   @SPICinemas @mano3493 already n8
# 35            @SPICinemas @AjayBha23009929 already n8
# 36              @SPICinemas @VinodhSundeep already n8
# 37                  @SPICinemas @iPradeepD already n8
# 38              @SPICinemas @VoiceOutforus already n8
# 39         @SPICinemas @VmsRohith @Rogshii already n8
# 40  @VettriTheatres Online tickets????????????????...
# 41  @GKcinemas #Whateverittakes Pls release #Aveng...
# 42  @SPICinemas @Marvel_India @IMAX #SPICinemas co...
# 43  @GKcinemas When will u release the tickets for...
# 44  @ForumVijayaMall @SPICinemas 1.SpaceStone - Te...
# 45  @massguna06gmai1 @rakkicinemas @MarvelStudios ...
# 46  @GoogleStadia @Google Am i suppose to buy 2 st...
# 47  Thank u @NASA  for bringing our @Iron_Man tony...
#
#     description  verified   age  followers      mentions  url_ratio  \
# 0            0         0  1336         35  1.7083333333   0.020833
#
#         hashtag  retweet_rate  mean_of_intertweet_delay         SD  \
# 0  0.2708333333           0.0                    4.5625  18.377232
#
#    avg_tweets_day  avg_tweeets_week
# 0        0.035928          0.251497

# %%
spam_words=["Ad","believe","Bargain","Amazed","Casino","Click","Collect","Cost","Coupons","Profits","Prize","Lucky","Congratulations","Credit","offers","Deal","Discount","Debt","Act","Additional","Billion","Bonus","Boss","Buy","free","hesitate","Extra","Double","Earn","Extra","Expire","Exciting","excited","Fantastic","gift","Get","Grab","Guarantee","Hurry","Increase","Junk","Limited","Link","Lowest","Luxury","Million","Make","miss","Money","marketing","Offer","opportunity","Order","Open","bucks","Please","Promise","Purchase","Rates","Refinance","Refund","Request","Risk","Spin","Sales","Satisfaction","Save","Score","Serious","Spam","Success","Supplies","Take","Terms","Traffic","Trial","Unlimited","Urgent","values","Weight","Win","Winner","waiting","lifetime","instant","delete","subscribe","unsubscribe"]

spam_sentence=["Double your","Earn extra cash","Earn per week","Expect to earn","Extra income","Home based","Home employment","Homebased business","Income from home","Make","Make money","click this link","Money making","Online biz opportunity","Online degree","While you sleep","Work at home","Work from home","One hundred percent free","Credit card offers","Lower interest rate","Month trial offer","you will not believe it","% off","percent off","no middleman","directly from company","limited period offer","you are a winner","you're a winner","free trial","apply","order","order now","new customers only","get it now","get started now","for just","great offer","give away","giving away","limited period offer","Incredible deal","Internet market","Internet marketing","It’s effective","Lower interest rate","Lowest interest rate","Lowest insurance rates","Lowest price","Luxury"]

# %%
spam_words=[x.lower() for x in spam_words]
spam_words = list(dict.fromkeys(spam_words))
print(spam_words)
len(spam_words)

spam_sentence=[x.lower() for x in spam_sentence]
spam_sentence = list(dict.fromkeys(spam_sentence))
print(spam_sentence)
len(spam_sentence)
# Out:
# ['ad', 'believe', 'bargain', 'amazed', 'casino', 'click', 'collect', 'cost', 'coupons', 'profits', 'prize', 'lucky', 'congratulations', 'credit', 'offers', 'deal', 'discount', 'debt', 'act', 'additional', 'billion', 'bonus', 'boss', 'buy', 'free', 'hesitate', 'extra', 'double', 'earn', 'expire', 'exciting', 'excited', 'fantastic', 'gift', 'get', 'grab', 'guarantee', 'hurry', 'increase', 'junk', 'limited', 'link', 'lowest', 'luxury', 'million', 'make', 'miss', 'money', 'marketing', 'offer', 'opportunity', 'order', 'open', 'bucks', 'please', 'promise', 'purchase', 'rates', 'refinance', 'refund', 'request', 'risk', 'spin', 'sales', 'satisfaction', 'save', 'score', 'serious', 'spam', 'success', 'supplies', 'take', 'terms', 'traffic', 'trial', 'unlimited', 'urgent', 'values', 'weight', 'win', 'winner', 'waiting', 'lifetime', 'instant', 'delete', 'subscribe', 'unsubscribe']
# ['double your', 'earn extra cash', 'earn per week', 'expect to earn', 'extra income', 'home based', 'home employment', 'homebased business', 'income from home', 'make', 'make money', 'click this link', 'money making', 'online biz opportunity', 'online degree', 'while you sleep', 'work at home', 'work from home', 'one hundred percent free', 'credit card offers', 'lower interest rate', 'month trial offer', 'you will not believe it', '% off', 'percent off', 'no middleman', 'directly from company', 'limited period offer', 'you are a winner', "you're a winner", 'free trial', 'apply', 'order', 'order now', 'new customers only', 'get it now', 'get started now', 'for just', 'great offer', 'give away', 'giving away', 'incredible deal', 'internet market', 'internet marketing', 'it’s effective', 'lowest interest rate', 'lowest insurance rates', 'lowest price', 'luxury']
# 49

# %%
spam_words = [word for word in spam_words if word.lower() not in stopwords.words('english')]

spam_sentence=[word for word in spam_sentence if word.lower() not in stopwords.words('english')]

# %%
print(spam_words)
# Out:
# ['ad', 'believe', 'bargain', 'amazed', 'casino', 'click', 'collect', 'cost', 'coupons', 'profits', 'prize', 'lucky', 'congratulations', 'credit', 'offers', 'deal', 'discount', 'debt', 'act', 'additional', 'billion', 'bonus', 'boss', 'buy', 'free', 'hesitate', 'extra', 'double', 'earn', 'expire', 'exciting', 'excited', 'fantastic', 'gift', 'get', 'grab', 'guarantee', 'hurry', 'increase', 'junk', 'limited', 'link', 'lowest', 'luxury', 'million', 'make', 'miss', 'money', 'marketing', 'offer', 'opportunity', 'order', 'open', 'bucks', 'please', 'promise', 'purchase', 'rates', 'refinance', 'refund', 'request', 'risk', 'spin', 'sales', 'satisfaction', 'save', 'score', 'serious', 'spam', 'success', 'supplies', 'take', 'terms', 'traffic', 'trial', 'unlimited', 'urgent', 'values', 'weight', 'win', 'winner', 'waiting', 'lifetime', 'instant', 'delete', 'subscribe', 'unsubscribe']

# %%
print(spam_sentence)
# Out:
# ['double your', 'earn extra cash', 'earn per week', 'expect to earn', 'extra income', 'home based', 'home employment', 'homebased business', 'income from home', 'make', 'make money', 'click this link', 'money making', 'online biz opportunity', 'online degree', 'while you sleep', 'work at home', 'work from home', 'one hundred percent free', 'credit card offers', 'lower interest rate', 'month trial offer', 'you will not believe it', '% off', 'percent off', 'no middleman', 'directly from company', 'limited period offer', 'you are a winner', "you're a winner", 'free trial', 'apply', 'order', 'order now', 'new customers only', 'get it now', 'get started now', 'for just', 'great offer', 'give away', 'giving away', 'incredible deal', 'internet market', 'internet marketing', 'it’s effective', 'lowest interest rate', 'lowest insurance rates', 'lowest price', 'luxury']

# %%
stemmer = SnowballStemmer("english")
spam_words=[stemmer.stem(i) for i in spam_words]

# %%
print(spam_words)
# Out:
# ['ad',
#  'believ',
#  'bargain',
#  'amaz',
#  'casino',
#  'click',
#  'collect',
#  'cost',
#  'coupon',
#  'profit',
#  'prize',
#  'lucki',
#  'congratul',
#  'credit',
#  'offer',
#  'deal',
#  'discount',
#  'debt',
#  'act',
#  'addit',
#  'billion',
#  'bonus',
#  'boss',
#  'buy',
#  'free',
#  'hesit',
#  'extra',
#  'doubl',
#  'earn',
#  'expir',
#  'excit',
#  'excit',
#  'fantast',
#  'gift',
#  'get',
#  'grab',
#  'guarante',
#  'hurri',
#  'increas',
#  'junk',
#  'limit',
#  'link',
#  'lowest',
#  'luxuri',
#  'million',
#  'make',
#  'miss',
#  'money',
#  'market',
#  'offer',
#  'opportun',
#  'order',
#  'open',
#  'buck',
#  'pleas',
#  'promis',
#  'purchas',
#  'rate',
#  'refin',
#  'refund',
#  'request',
#  'risk',
#  'spin',
#  'sale',
#  'satisfact',
#  'save',
#  'score',
#  'serious',
#  'spam',
#  'success',
#  'suppli',
#  'take',
#  'term',
#  'traffic',
#  'trial',
#  'unlimit',
#  'urgent',
#  'valu',
#  'weight',
#  'win',
#  'winner',
#  'wait',
#  'lifetim',
#  'instant',
#  'delet',
#  'subscrib',
#  'unsubscrib']

# %%
tweet="Hurry Hurry Hurry! Click this link to grab the offer! and be Amazed! and get a bonus of 1 lakh"

tweet = tweet.translate(str.maketrans('', '', string.punctuation))
tweet = [word for word in tweet.split() if word.lower() not in stopwords.words('english')]
words = []
for i in tweet:
    stemmer = SnowballStemmer("english")
    words.append(stemmer.stem(i))

# %%
print(words)
# Out:
# ['hurri',
#  'hurri',
#  'hurri',
#  'click',
#  'link',
#  'grab',
#  'offer',
#  'amaz',
#  'get',
#  'bonus',
#  '1',
#  'lakh']

# %%
words = list(dict.fromkeys(words))

# %%
print(words)
# Out:
# ['hurri',
#  'click',
#  'link',
#  'grab',
#  'offer',
#  'amaz',
#  'get',
#  'bonus',
#  '1',
#  'lakh']

# %%
len(words)
# Out:
# 10

# %%
count=0
for i in words:
    if i in spam_words:
        count+=1
count
# Out:
# 8

# %%
score=(count/len(words))
score
# Out:
# 0.8

# %%
tweet_df
# Out:
#                                                 Tweet
# 0          @No_PlasticWaste @minderoo @TEDchris hello
# 1           #RiseofSkywalker  https://t.co/LtkO3psEBX
# 2   @JaipurPanthers Even the commentary says. But ...
# 3                                   @_PVRCinemas puli
# 4    @CarnivalCine movie release date  30 or 31 ?????
# 5   @CarnivalCine Godzilla movie Evp la viduvingal...
# 6   @CarnivalCine When will you release the ticket...
# 7   @CarnivalCine #ironman dies and #captainameric...
# 8   @SPICinemas @hackiz @vrlokesh1992 i dont need ...
# 9          @SPICinemas @BagathSanju Enough already n8
# 10                     @SPICinemas @sbk585 already n8
# 11            @SPICinemas @bnikhileshwarre already n8
# 12              @SPICinemas @fosterjack631 already n8
# 13              @SPICinemas @gokulrock1702 already n8
# 14            @SPICinemas @SudarshanSivak1 already n8
# 15              @SPICinemas @gokul60699263 already n8
# 16                @SPICinemas @KrizzArvind already n8
# 17                 @SPICinemas @rafi200331 already n8
# 18            @SPICinemas @SanjayC91429472 already n8
# 19              @SPICinemas @Surya83740256 already n8
# 20                    @SPICinemas @Rogshii already n8
# 21            @SPICinemas @Yashwan48643397 already n8
# 22  @SPICinemas @PrakashKathir7 @TheCinemabySPI al...
# 23   @SPICinemas @saravana_assr In Chennai already n8
# 24             @SPICinemas @S__ViNoDhKuMaR already n8
# 25            @SPICinemas @IlayaBharathi14 already n8
# 26                  @SPICinemas @raaghul06 already n8
# 27            @SPICinemas @Anbulogachandr1 already n8
# 28               @SPICinemas @tarun_aadith already n8
# 29                  @SPICinemas @arif_1305 already n8
# 30                  @SPICinemas @Bheembwoy already n8
# 31                @SPICinemas @AkashAk2812 already n8
# 32                @SPICinemas @siddhubalaj already n8
# 33                 @SPICinemas @Havinash20 already n8
# 34                   @SPICinemas @mano3493 already n8
# 35            @SPICinemas @AjayBha23009929 already n8
# 36              @SPICinemas @VinodhSundeep already n8
# 37                  @SPICinemas @iPradeepD already n8
# 38              @SPICinemas @VoiceOutforus already n8
# 39         @SPICinemas @VmsRohith @Rogshii already n8
# 40  @VettriTheatres Online tickets????????????????...
# 41  @GKcinemas #Whateverittakes Pls release #Aveng...
# 42  @SPICinemas @Marvel_India @IMAX #SPICinemas co...
# 43  @GKcinemas When will u release the tickets for...
# 44  @ForumVijayaMall @SPICinemas 1.SpaceStone - Te...
# 45  @massguna06gmai1 @rakkicinemas @MarvelStudios ...
# 46  @GoogleStadia @Google Am i suppose to buy 2 st...
# 47  Thank u @NASA  for bringing our @Iron_Man tony...

# %%
tweet=tweet_df.copy()

# %%
tweet
# Out:
#                                                 Tweet
# 0          @No_PlasticWaste @minderoo @TEDchris hello
# 1           #RiseofSkywalker  https://t.co/LtkO3psEBX
# 2   @JaipurPanthers Even the commentary says. But ...
# 3                                   @_PVRCinemas puli
# 4    @CarnivalCine movie release date  30 or 31 ?????
# 5   @CarnivalCine Godzilla movie Evp la viduvingal...
# 6   @CarnivalCine When will you release the ticket...
# 7   @CarnivalCine #ironman dies and #captainameric...
# 8   @SPICinemas @hackiz @vrlokesh1992 i dont need ...
# 9          @SPICinemas @BagathSanju Enough already n8
# 10                     @SPICinemas @sbk585 already n8
# 11            @SPICinemas @bnikhileshwarre already n8
# 12              @SPICinemas @fosterjack631 already n8
# 13              @SPICinemas @gokulrock1702 already n8
# 14            @SPICinemas @SudarshanSivak1 already n8
# 15              @SPICinemas @gokul60699263 already n8
# 16                @SPICinemas @KrizzArvind already n8
# 17                 @SPICinemas @rafi200331 already n8
# 18            @SPICinemas @SanjayC91429472 already n8
# 19              @SPICinemas @Surya83740256 already n8
# 20                    @SPICinemas @Rogshii already n8
# 21            @SPICinemas @Yashwan48643397 already n8
# 22  @SPICinemas @PrakashKathir7 @TheCinemabySPI al...
# 23   @SPICinemas @saravana_assr In Chennai already n8
# 24             @SPICinemas @S__ViNoDhKuMaR already n8
# 25            @SPICinemas @IlayaBharathi14 already n8
# 26                  @SPICinemas @raaghul06 already n8
# 27            @SPICinemas @Anbulogachandr1 already n8
# 28               @SPICinemas @tarun_aadith already n8
# 29                  @SPICinemas @arif_1305 already n8
# 30                  @SPICinemas @Bheembwoy already n8
# 31                @SPICinemas @AkashAk2812 already n8
# 32                @SPICinemas @siddhubalaj already n8
# 33                 @SPICinemas @Havinash20 already n8
# 34                   @SPICinemas @mano3493 already n8
# 35            @SPICinemas @AjayBha23009929 already n8
# 36              @SPICinemas @VinodhSundeep already n8
# 37                  @SPICinemas @iPradeepD already n8
# 38              @SPICinemas @VoiceOutforus already n8
# 39         @SPICinemas @VmsRohith @Rogshii already n8
# 40  @VettriTheatres Online tickets????????????????...
# 41  @GKcinemas #Whateverittakes Pls release #Aveng...
# 42  @SPICinemas @Marvel_India @IMAX #SPICinemas co...
# 43  @GKcinemas When will u release the tickets for...
# 44  @ForumVijayaMall @SPICinemas 1.SpaceStone - Te...
# 45  @massguna06gmai1 @rakkicinemas @MarvelStudios ...
# 46  @GoogleStadia @Google Am i suppose to buy 2 st...
# 47  Thank u @NASA  for bringing our @Iron_Man tony...

# %%
tweet['Score']=0.0

# %%
tweet
# Out:
#                                                 Tweet  Score
# 0          @No_PlasticWaste @minderoo @TEDchris hello    0.0
# 1           #RiseofSkywalker  https://t.co/LtkO3psEBX    0.0
# 2   @JaipurPanthers Even the commentary says. But ...    0.0
# 3                                   @_PVRCinemas puli    0.0
# 4    @CarnivalCine movie release date  30 or 31 ?????    0.0
# 5   @CarnivalCine Godzilla movie Evp la viduvingal...    0.0
# 6   @CarnivalCine When will you release the ticket...    0.0
# 7   @CarnivalCine #ironman dies and #captainameric...    0.0
# 8   @SPICinemas @hackiz @vrlokesh1992 i dont need ...    0.0
# 9          @SPICinemas @BagathSanju Enough already n8    0.0
# 10                     @SPICinemas @sbk585 already n8    0.0
# 11            @SPICinemas @bnikhileshwarre already n8    0.0
# 12              @SPICinemas @fosterjack631 already n8    0.0
# 13              @SPICinemas @gokulrock1702 already n8    0.0
# 14            @SPICinemas @SudarshanSivak1 already n8    0.0
# 15              @SPICinemas @gokul60699263 already n8    0.0
# 16                @SPICinemas @KrizzArvind already n8    0.0
# 17                 @SPICinemas @rafi200331 already n8    0.0
# 18            @SPICinemas @SanjayC91429472 already n8    0.0
# 19              @SPICinemas @Surya83740256 already n8    0.0
# 20                    @SPICinemas @Rogshii already n8    0.0
# 21            @SPICinemas @Yashwan48643397 already n8    0.0
# 22  @SPICinemas @PrakashKathir7 @TheCinemabySPI al...    0.0
# 23   @SPICinemas @saravana_assr In Chennai already n8    0.0
# 24             @SPICinemas @S__ViNoDhKuMaR already n8    0.0
# 25            @SPICinemas @IlayaBharathi14 already n8    0.0
# 26                  @SPICinemas @raaghul06 already n8    0.0
# 27            @SPICinemas @Anbulogachandr1 already n8    0.0
# 28               @SPICinemas @tarun_aadith already n8    0.0
# 29                  @SPICinemas @arif_1305 already n8    0.0
# 30                  @SPICinemas @Bheembwoy already n8    0.0
# 31                @SPICinemas @AkashAk2812 already n8    0.0
# 32                @SPICinemas @siddhubalaj already n8    0.0
# 33                 @SPICinemas @Havinash20 already n8    0.0
# 34                   @SPICinemas @mano3493 already n8    0.0
# 35            @SPICinemas @AjayBha23009929 already n8    0.0
# 36              @SPICinemas @VinodhSundeep already n8    0.0
# 37                  @SPICinemas @iPradeepD already n8    0.0
# 38              @SPICinemas @VoiceOutforus already n8    0.0
# 39         @SPICinemas @VmsRohith @Rogshii already n8    0.0
# 40  @VettriTheatres Online tickets????????????????...    0.0
# 41  @GKcinemas #Whateverittakes Pls release #Aveng...    0.0
# 42  @SPICinemas @Marvel_India @IMAX #SPICinemas co...    0.0
# 43  @GKcinemas When will u release the tickets for...    0.0
# 44  @ForumVijayaMall @SPICinemas 1.SpaceStone - Te...    0.0
# 45  @massguna06gmai1 @rakkicinemas @MarvelStudios ...    0.0
# 46  @GoogleStadia @Google Am i suppose to buy 2 st...    0.0
# 47  Thank u @NASA  for bringing our @Iron_Man tony...    0.0

# %%
#tweet="Hurry Hurry Hurry! Click this link to grab the offer! and be Amazed! and get a bonus of 1 lakh"
index=0
for i in tweet['Tweet']:
    i = i.translate(str.maketrans('', '', string.punctuation))
    i = [word for word in i.split() if word.lower() not in stopwords.words('english')]
    #print(i)
    words = []
    for j in i:
        stemmer = SnowballStemmer("english")
        words.append(stemmer.stem(j))
    print(words)
    words = list(dict.fromkeys(words))
    len(words)
    count=0
    for i in words:
        if i in spam_words:
            count+=1
    for sentence in spam_sentence:
        #x=tweet1.in(sentence)
        if sentence in i:
            #if(x):
            count+=1
    score=(count/len(words))
    tweet.Score[index]=score
    index+=1
# Out:
# ['noplasticwast', 'minderoo', 'tedchri', 'hello']
# ['riseofskywalk', 'httpstcoltko3psebx']
# ['jaipurpanth', 'even', 'commentari', 'say', 'umpir', 'cantwhatta', 'fuck', '😑', 'chevsjai', 'vivoprokabaddi', 'issetoughkuchnahi']
# ['pvrcinema', 'puli']
# ['carnivalcin', 'movi', 'releas', 'date', '30', '31']
# ['carnivalcin', 'godzilla', 'movi', 'evp', 'la', 'viduvingala', 'ilauyareleas', 'pandringana', 'ticket', 'epa', 'vidaporinga']
# ['carnivalcin', 'releas', 'ticket', 'godzilla', '2english']
# ['carnivalcin', 'ironman', 'die', 'captainamerica', 'stay', 'past', 'girlfriend', 'stupid', 'frnd', 'spoil', '2', 'spoiler']
# ['spicinema', 'hackiz', 'vrlokesh1992', 'dont', 'need', 'ur', 'ticket', 'httpstcotelcan1qfl']
# ['spicinema', 'bagathsanju', 'enough', 'alreadi', 'n8']
# ['spicinema', 'sbk585', 'alreadi', 'n8']
# ['spicinema', 'bnikhileshwarr', 'alreadi', 'n8']
# ['spicinema', 'fosterjack631', 'alreadi', 'n8']
# ['spicinema', 'gokulrock1702', 'alreadi', 'n8']
# ['spicinema', 'sudarshansivak1', 'alreadi', 'n8']
# ['spicinema', 'gokul60699263', 'alreadi', 'n8']
# ['spicinema', 'krizzarvind', 'alreadi', 'n8']
# ['spicinema', 'rafi200331', 'alreadi', 'n8']
# ['spicinema', 'sanjayc91429472', 'alreadi', 'n8']
# ['spicinema', 'surya83740256', 'alreadi', 'n8']
# ['spicinema', 'rogshii', 'alreadi', 'n8']
# ['spicinema', 'yashwan48643397', 'alreadi', 'n8']
# ['spicinema', 'prakashkathir7', 'thecinemabyspi', 'alreadi', 'n8']
# ['spicinema', 'saravanaassr', 'chennai', 'alreadi', 'n8']
# ['spicinema', 'svinodhkumar', 'alreadi', 'n8']
# ['spicinema', 'ilayabharathi14', 'alreadi', 'n8']
# ['spicinema', 'raaghul06', 'alreadi', 'n8']
# ['spicinema', 'anbulogachandr1', 'alreadi', 'n8']
# ['spicinema', 'tarunaadith', 'alreadi', 'n8']
# ['spicinema', 'arif1305', 'alreadi', 'n8']
# ['spicinema', 'bheembwoy', 'alreadi', 'n8']
# ['spicinema', 'akashak2812', 'alreadi', 'n8']
# ['spicinema', 'siddhubalaj', 'alreadi', 'n8']
# ['spicinema', 'havinash20', 'alreadi', 'n8']
# ['spicinema', 'mano3493', 'alreadi', 'n8']
# ['spicinema', 'ajaybha23009929', 'alreadi', 'n8']
# ['spicinema', 'vinodhsundeep', 'alreadi', 'n8']
# ['spicinema', 'ipradeepd', 'alreadi', 'n8']
# ['spicinema', 'voiceoutforus', 'alreadi', 'n8']
# ['spicinema', 'vmsrohith', 'rogshii', 'alreadi', 'n8']
# ['vettritheatr', 'onlin', 'tickets😢😢😢😢']
# ['gkcinema', 'whateverittak', 'pls', 'releas', 'avengersendgam', 'ticket', 'could', 'u', 'specif', 'abt', 'book', 'tim…', 'httpstcohrh0zlkv3']
# ['spicinema', 'marvelindia', 'imax', 'spicinema', 'could', 'u', 'apecif', 'abt', 'time', 'avengersendgam', 'bookingplsssssssss']
# ['gkcinema', 'u', 'releas', 'ticket', 'endgam', 'rgb', 'plus']
# ['forumvijayamal', 'spicinema', '1spaceston', 'tesseract', 'thor', '2mindston', 'chitauri', 'scepter', 'loki…', 'httpstco2zk0rvycom']
# ['massguna06gmai1', 'rakkicinema', 'marvelstudio', 'tonight', '11pm']
# ['googlestadia', 'googl', 'suppos', 'buy', '2', 'stadia', '2', 'player', '3', 'stadia', '3', 'player', '🤔🤔🤔']
# ['thank', 'u', 'nasa', 'bring', 'ironman', 'toni', 'back', 'earthlet', 'hope', 'aveng', 'save', 'worldamerica', 'again…', 'httpstco9culwxkuho']
# C:\Users\santh\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tweet
# Out:
#                                                 Tweet     Score
# 0          @No_PlasticWaste @minderoo @TEDchris hello  0.000000
# 1           #RiseofSkywalker  https://t.co/LtkO3psEBX  0.000000
# 2   @JaipurPanthers Even the commentary says. But ...  0.000000
# 3                                   @_PVRCinemas puli  0.000000
# 4    @CarnivalCine movie release date  30 or 31 ?????  0.000000
# 5   @CarnivalCine Godzilla movie Evp la viduvingal...  0.000000
# 6   @CarnivalCine When will you release the ticket...  0.000000
# 7   @CarnivalCine #ironman dies and #captainameric...  0.000000
# 8   @SPICinemas @hackiz @vrlokesh1992 i dont need ...  0.000000
# 9          @SPICinemas @BagathSanju Enough already n8  0.000000
# 10                     @SPICinemas @sbk585 already n8  0.000000
# 11            @SPICinemas @bnikhileshwarre already n8  0.000000
# 12              @SPICinemas @fosterjack631 already n8  0.000000
# 13              @SPICinemas @gokulrock1702 already n8  0.000000
# 14            @SPICinemas @SudarshanSivak1 already n8  0.000000
# 15              @SPICinemas @gokul60699263 already n8  0.000000
# 16                @SPICinemas @KrizzArvind already n8  0.000000
# 17                 @SPICinemas @rafi200331 already n8  0.000000
# 18            @SPICinemas @SanjayC91429472 already n8  0.000000
# 19              @SPICinemas @Surya83740256 already n8  0.000000
# 20                    @SPICinemas @Rogshii already n8  0.000000
# 21            @SPICinemas @Yashwan48643397 already n8  0.000000
# 22  @SPICinemas @PrakashKathir7 @TheCinemabySPI al...  0.000000
# 23   @SPICinemas @saravana_assr In Chennai already n8  0.000000
# 24             @SPICinemas @S__ViNoDhKuMaR already n8  0.000000
# 25            @SPICinemas @IlayaBharathi14 already n8  0.000000
# 26                  @SPICinemas @raaghul06 already n8  0.000000
# 27            @SPICinemas @Anbulogachandr1 already n8  0.000000
# 28               @SPICinemas @tarun_aadith already n8  0.000000
# 29                  @SPICinemas @arif_1305 already n8  0.000000
# 30                  @SPICinemas @Bheembwoy already n8  0.000000
# 31                @SPICinemas @AkashAk2812 already n8  0.000000
# 32                @SPICinemas @siddhubalaj already n8  0.000000
# 33                 @SPICinemas @Havinash20 already n8  0.000000
# 34                   @SPICinemas @mano3493 already n8  0.000000
# 35            @SPICinemas @AjayBha23009929 already n8  0.000000
# 36              @SPICinemas @VinodhSundeep already n8  0.000000
# 37                  @SPICinemas @iPradeepD already n8  0.000000
# 38              @SPICinemas @VoiceOutforus already n8  0.000000
# 39         @SPICinemas @VmsRohith @Rogshii already n8  0.000000
# 40  @VettriTheatres Online tickets????????????????...  0.000000
# 41  @GKcinemas #Whateverittakes Pls release #Aveng...  0.000000
# 42  @SPICinemas @Marvel_India @IMAX #SPICinemas co...  0.000000
# 43  @GKcinemas When will u release the tickets for...  0.000000
# 44  @ForumVijayaMall @SPICinemas 1.SpaceStone - Te...  0.000000
# 45  @massguna06gmai1 @rakkicinemas @MarvelStudios ...  0.000000
# 46  @GoogleStadia @Google Am i suppose to buy 2 st...  0.111111
# 47  Thank u @NASA  for bringing our @Iron_Man tony...  0.071429

# %%
tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweet   48 non-null     object
#  1   Score   48 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 896.0+ bytes

# %%
tweet.dtypes
# Out:
# Tweet     object
# Score    float64
# dtype: object

# %%
#tweet.Score=tweet.Score.astype(float)

# %%
#tweet.dtypes

# %%
tweet.Score.describe()
# Out:
# count    48.000000
# mean      0.003803
# std       0.018880
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       0.111111
# Name: Score, dtype: float64
