# %%
# %run extract.ipynb
# Out:
# number of followers count :  34
#  user id :  754570151538757634
# follower ids : [755317824638246912, 1225279175302344705, 999254204932763648, 1167128409085890560, 1142386746694332416, 273423046, 1047311216937508864, 1084446431987957761, 739090111338401792, 942032173388898304, 1042276383098003456, 1026048180704575488, 1009850528765902848, 953189299599503360, 1009783190800789504, 909379865559756802, 992414541186191361, 719838504327352320, 945594464063467520, 930744964627120128, 876428483408273413, 822913800529727488, 820549404511916032, 800347753133928448, 815091329793490944, 1922516666, 755024958712012801, 3274509678, 786065106530603008, 756102342924046336, 740865625233334272, 757531961426489344, 2409048883, 752528322270081024]
# Getting data for @UdhayavannanUvi
# name: A.Udhayavannan
# screen_name: UdhayavannanUvi
# description:
# statuses_count:  48
# friends_count:  107
# followers_count:  34
# favourites count: 17
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Thu Oct 24 05:34:47 +0000 2019', 'id': 1187241001343078400, 'id_str': '1187241001343078400', 'text': '@No_PlasticWaste @minderoo @TEDchris hello', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'No_PlasticWaste', 'name': 'No Plastic Waste', 'id': 1170057621832777728, 'id_str': '1170057621832777728', 'indices': [0, 16]}, {'screen_name': 'minderoo', 'name': 'Minderoo Foundation', 'id': 1853845165, 'id_str': '1853845165', 'indices': [17, 26]}, {'screen_name': 'TEDchris', 'name': 'Chris Anderson', 'id': 14761795, 'id_str': '14761795', 'indices': [27, 36]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1181751063000604672, 'in_reply_to_status_id_str': '1181751063000604672', 'in_reply_to_user_id': 1170057621832777728, 'in_reply_to_user_id_str': '1170057621832777728', 'in_reply_to_screen_name': 'No_PlasticWaste', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 10, 24, 5, 34, 47), id=1187241001343078400, id_str='1187241001343078400', text='@No_PlasticWaste @minderoo @TEDchris hello', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'No_PlasticWaste', 'name': 'No Plastic Waste', 'id': 1170057621832777728, 'id_str': '1170057621832777728', 'indices': [0, 16]}, {'screen_name': 'minderoo', 'name': 'Minderoo Foundation', 'id': 1853845165, 'id_str': '1853845165', 'indices': [17, 26]}, {'screen_name': 'TEDchris', 'name': 'Chris Anderson', 'id': 14761795, 'id_str': '14761795', 'indices': [27, 36]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1181751063000604672, in_reply_to_status_id_str='1181751063000604672', in_reply_to_user_id=1170057621832777728, in_reply_to_user_id_str='1170057621832777728', in_reply_to_screen_name='No_PlasticWaste', geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  False
# has extended profile:  True
# id : 754570151538757634
# id_str : 754570151538757634
# location :
# url :  None
# creation date 2016-07-17 06:55:18
# created date =  2016-07-17 06:55:18
# 1487 days, 6:06:57.085737
# Account age (in days): 1487
# Average tweets per day: 0.03
# tweet count 48
#
# 44
# 79
#
# Most used hashtags:
# AvengersEndgame	2
# RiseofSkywalker	1
# CHEvsJAI	1
# vivoProKabaddi	1
# IsseToughKuchNahi	1
# ironman	1
# captainamerica	1
# Whateverittakes	1
# SPICinemas	1
# endgame	1
# reputation =  0.2411347518
# mentions raitio =  1.6458333333
# hashtag_ratio = 0.2708333333
# unique mentions = 0.5569620253
# All done. Processed 48 tweets.
# 2019-10-24 05:34:47
# 0
# 2019-10-24 04:37:42
# 0
# 2019-08-21 16:23:05
# 0
# 2019-07-10 14:21:34
# 0
# 2019-05-28 04:07:27
# 0
# 2019-05-27 03:29:58
# 0
# 2019-05-27 03:24:59
# 0
# 2019-04-25 14:51:13
# 0
# 2019-04-24 01:27:16
# 0
# 2019-04-23 15:59:15
# 0
# 2019-04-23 15:58:48
# 0
# 2019-04-23 15:58:40
# 0
# 2019-04-23 15:58:21
# 0
# 2019-04-23 15:58:07
# 0
# 2019-04-23 15:57:59
# 0
# 2019-04-23 15:57:52
# 0
# 2019-04-23 15:57:46
# 0
# 2019-04-23 15:57:38
# 0
# 2019-04-23 15:57:30
# 0
# 2019-04-23 15:57:21
# 0
# 2019-04-23 15:57:08
# 0
# 2019-04-23 15:56:54
# 0
# 2019-04-23 15:56:48
# 0
# 2019-04-23 15:56:19
# 0
# 2019-04-23 15:55:44
# 0
# 2019-04-23 15:55:28
# 0
# 2019-04-23 15:55:18
# 0
# 2019-04-23 15:55:07
# 0
# 2019-04-23 15:54:57
# 0
# 2019-04-23 15:54:48
# 0
# 2019-04-23 15:54:39
# 0
# 2019-04-23 15:54:30
# 0
# 2019-04-23 15:54:21
# 0
# 2019-04-23 15:54:10
# 0
# 2019-04-23 15:53:52
# 0
# 2019-04-23 15:53:43
# 0
# 2019-04-23 15:53:36
# 0
# 2019-04-23 15:53:26
# 0
# 2019-04-23 15:53:14
# 0
# 2019-04-23 15:53:02
# 0
# 2019-04-23 12:54:42
# 0
# 2019-04-23 11:54:02
# 0
# 2019-04-23 11:45:08
# 0
# 2019-04-23 06:56:27
# 0
# 2019-04-22 15:34:29
# 0
# 2019-04-22 15:02:05
# 0
# 2019-04-19 00:44:04
# 0
# 2019-03-14 16:20:37
# 0
# total intertweet_delay 219
# mean_of_intertweet_delay  4.5625
# sd of intertweet delay  18.3772320073
# avg_tweets day and week 0.0322797579   0.2259583053
# twitter urls :
# url posted by user:
# https://t.co/LtkO3psEBX
# twitter urls :
# https://t.co/HRh0zlKv3S
# {'hashtags': [{'text': 'Whateverittakes', 'indices': [11, 27]}, {'text': 'AvengersEndgame', 'indices': [40, 56]}], 'symbols': [], 'user_mentions': [{'screen_name': 'GKcinemas', 'name': 'Ruban Mathivanan', 'id': 128495725, 'id_str': '128495725', 'indices': [0, 10]}], 'urls': [{'url': 'https://t.co/HRh0zlKv3S', 'expanded_url': 'https://twitter.com/i/web/status/1120657078115164162', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}
#
#
# twitter urls :
# https://t.co/2ZK0rvycom
# {'hashtags': [{'text': 'Thor', 'indices': [57, 62]}, {'text': 'Loki', 'indices': [94, 99]}], 'symbols': [], 'user_mentions': [{'screen_name': 'SPICinemas', 'name': 'S P I C i n e m a s', 'id': 919079586, 'id_str': '919079586', 'indices': [17, 28]}], 'urls': [{'url': 'https://t.co/2ZK0rvycom', 'expanded_url': 'https://twitter.com/i/web/status/1120350168258187264', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [101, 124]}]}
#
#
# twitter urls :
# https://t.co/9culWXKUHO
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'NASA', 'name': 'NASA', 'id': 11348282, 'id_str': '11348282', 'indices': [8, 13]}, {'screen_name': 'Iron_Man', 'name': 'Iron Man', 'id': 570218986, 'id_str': '570218986', 'indices': [32, 41]}, {'screen_name': 'Avengers', 'name': 'The Avengers', 'id': 393852070, 'id_str': '393852070', 'indices': [71, 80]}], 'urls': [{'url': 'https://t.co/9culWXKUHO', 'expanded_url': 'https://twitter.com/i/web/status/1106228648732819457', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}
#
#
# url count is  1
# url ratio is  0.0208333333
# retweet rate is  0.0
# No_PlasticWaste
# None
# JaipurPanthers
# _PVRCinemas
# None
# None
# None
# None
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# SPICinemas
# VettriTheatres
# GKcinemas
# SPICinemas
# GKcinemas
# ForumVijayaMall
# massguna06gmai1
# GoogleStadia
# None
# retweet rate is  0.875
# Getting data for @UdhayavannanUvi
# False
# 0
#
#
# user_id is  755317824638246912
# name: Vinuvarsidh
# screen_name: vinuvarsidh
# description:
# statuses_count:  11
# friends_count:  101
# followers_count:  6
# favourites count: 35
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Wed Aug 12 04:03:00 +0000 2020', 'id': 1293397549634613249, 'id_str': '1293397549634613249', 'text': '@PeteLau Iam not hating new design elements in the UI. BUT part of what made oxygen os great in the first place (mi… https://t.co/W0Sbo31A5i', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PeteLau', 'name': 'Pete Lau', 'id': 226813577, 'id_str': '226813577', 'indices': [0, 8]}], 'urls': [{'url': 'https://t.co/W0Sbo31A5i', 'expanded_url': 'https://twitter.com/i/web/status/1293397549634613249', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1291767641552687104, 'in_reply_to_status_id_str': '1291767641552687104', 'in_reply_to_user_id': 226813577, 'in_reply_to_user_id_str': '226813577', 'in_reply_to_screen_name': 'PeteLau', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 8, 12, 4, 3), id=1293397549634613249, id_str='1293397549634613249', text='@PeteLau Iam not hating new design elements in the UI. BUT part of what made oxygen os great in the first place (mi… https://t.co/W0Sbo31A5i', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PeteLau', 'name': 'Pete Lau', 'id': 226813577, 'id_str': '226813577', 'indices': [0, 8]}], 'urls': [{'url': 'https://t.co/W0Sbo31A5i', 'expanded_url': 'https://twitter.com/i/web/status/1293397549634613249', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1291767641552687104, in_reply_to_status_id_str='1291767641552687104', in_reply_to_user_id=226813577, in_reply_to_user_id_str='226813577', in_reply_to_screen_name='PeteLau', geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=1, favorited=False, retweeted=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  True
# has extended profile:  False
# id : 755317824638246912
# id_str : 755317824638246912
# location :
# url :  None
# created date =  2016-07-19 08:26:17
# 1485 days, 4:36:14.271411
# Account age (in days): 1485
# False
# followers data is  [755317824638246912, '755317824638246912', 'vinuvarsidh', '', '', None, 6, 101, 0, datetime.datetime(2016, 7, 19, 8, 26, 17), 35, False, 11, None, 'Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Wed Aug 12 04:03:00 +0000 2020\', \'id\': 1293397549634613249, \'id_str\': \'1293397549634613249\', \'text\': \'@PeteLau Iam not hating new design elements in the UI. BUT part of what made oxygen os great in the first place (mi… https://t.co/W0Sbo31A5i\', \'truncated\': True, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'PeteLau\', \'name\': \'Pete Lau\', \'id\': 226813577, \'id_str\': \'226813577\', \'indices\': [0, 8]}], \'urls\': [{\'url\': \'https://t.co/W0Sbo31A5i\', \'expanded_url\': \'https://twitter.com/i/web/status/1293397549634613249\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': 1291767641552687104, \'in_reply_to_status_id_str\': \'1291767641552687104\', \'in_reply_to_user_id\': 226813577, \'in_reply_to_user_id_str\': \'226813577\', \'in_reply_to_screen_name\': \'PeteLau\', \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 1, \'favorited\': False, \'retweeted\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2020, 8, 12, 4, 3), id=1293397549634613249, id_str=\'1293397549634613249\', text=\'@PeteLau Iam not hating new design elements in the UI. BUT part of what made oxygen os great in the first place (mi… https://t.co/W0Sbo31A5i\', truncated=True, entities={\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'PeteLau\', \'name\': \'Pete Lau\', \'id\': 226813577, \'id_str\': \'226813577\', \'indices\': [0, 8]}], \'urls\': [{\'url\': \'https://t.co/W0Sbo31A5i\', \'expanded_url\': \'https://twitter.com/i/web/status/1293397549634613249\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [117, 140]}]}, source=\'Twitter for Android\', source_url=\'http://twitter.com/download/android\', in_reply_to_status_id=1291767641552687104, in_reply_to_status_id_str=\'1291767641552687104\', in_reply_to_user_id=226813577, in_reply_to_user_id_str=\'226813577\', in_reply_to_screen_name=\'PeteLau\', geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=1, favorited=False, retweeted=False, lang=\'en\')', 'True', 'True', 'False', 'Vinuvarsidh']
#
#
# user_id is  1225279175302344705
# name: Terminator
# screen_name: Terminatorz_
# description:
# statuses_count:  2
# friends_count:  6
# followers_count:  1
# favourites count: 0
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Thu Feb 13 04:10:15 +0000 2020', 'id': 1227807170260951045, 'id_str': '1227807170260951045', 'text': 'recently bought note 8 pro, and this is the best phone to buy under 15k . @note8pro , @mi #note8pro ,#mifan', 'truncated': False, 'entities': {'hashtags': [{'text': 'note8pro', 'indices': [90, 99]}, {'text': 'mifan', 'indices': [101, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'note8pro', 'name': 'Note8pro', 'id': 1239148356141711360, 'id_str': '1239148356141711360', 'indices': [74, 83]}, {'screen_name': 'mi', 'name': 'محمد', 'id': 259918248, 'id_str': '259918248', 'indices': [86, 89]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 2, 13, 4, 10, 15), id=1227807170260951045, id_str='1227807170260951045', text='recently bought note 8 pro, and this is the best phone to buy under 15k . @note8pro , @mi #note8pro ,#mifan', truncated=False, entities={'hashtags': [{'text': 'note8pro', 'indices': [90, 99]}, {'text': 'mifan', 'indices': [101, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'note8pro', 'name': 'Note8pro', 'id': 1239148356141711360, 'id_str': '1239148356141711360', 'indices': [74, 83]}, {'screen_name': 'mi', 'name': 'محمد', 'id': 259918248, 'id_str': '259918248', 'indices': [86, 89]}], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  True
# has extended profile:  False
# id : 1225279175302344705
# id_str : 1225279175302344705
# location :
# url :  None
# created date =  2020-02-06 04:45:06
# 188 days, 8:17:26.631356
# Account age (in days): 188
# False
# followers data is  [1225279175302344705, '1225279175302344705', 'Terminatorz_', '', '', None, 1, 6, 0, datetime.datetime(2020, 2, 6, 4, 45, 6), 0, False, 2, None, 'Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Thu Feb 13 04:10:15 +0000 2020\', \'id\': 1227807170260951045, \'id_str\': \'1227807170260951045\', \'text\': \'recently bought note 8 pro, and this is the best phone to buy under 15k . @note8pro , @mi #note8pro ,#mifan\', \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'note8pro\', \'indices\': [90, 99]}, {\'text\': \'mifan\', \'indices\': [101, 107]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'note8pro\', \'name\': \'Note8pro\', \'id\': 1239148356141711360, \'id_str\': \'1239148356141711360\', \'indices\': [74, 83]}, {\'screen_name\': \'mi\', \'name\': \'محمد\', \'id\': 259918248, \'id_str\': \'259918248\', \'indices\': [86, 89]}], \'urls\': []}, \'source\': \'<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2020, 2, 13, 4, 10, 15), id=1227807170260951045, id_str=\'1227807170260951045\', text=\'recently bought note 8 pro, and this is the best phone to buy under 15k . @note8pro , @mi #note8pro ,#mifan\', truncated=False, entities={\'hashtags\': [{\'text\': \'note8pro\', \'indices\': [90, 99]}, {\'text\': \'mifan\', \'indices\': [101, 107]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'note8pro\', \'name\': \'Note8pro\', \'id\': 1239148356141711360, \'id_str\': \'1239148356141711360\', \'indices\': [74, 83]}, {\'screen_name\': \'mi\', \'name\': \'محمد\', \'id\': 259918248, \'id_str\': \'259918248\', \'indices\': [86, 89]}], \'urls\': []}, source=\'Twitter Web App\', source_url=\'https://mobile.twitter.com\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang=\'en\')', 'True', 'True', 'False', 'Terminator']
#
#
# user_id is  999254204932763648
# name: Prabhu
# screen_name: Imprabhu15
# description:
# statuses_count:  7
# friends_count:  171
# followers_count:  18
# favourites count: 63
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Sun Jul 26 11:14:46 +0000 2020', 'id': 1287345611885301760, 'id_str': '1287345611885301760', 'text': 'RT @ammumanuu: #WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\n#EIA2020 #EIA2020draft #…', 'truncated': False, 'entities': {'hashtags': [{'text': 'WithdrawDraftEIA2020', 'indices': [15, 36]}, {'text': 'EIA2020', 'indices': [115, 123]}, {'text': 'EIA2020draft', 'indices': [124, 137]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ammumanuu', 'name': 'Ammu', 'id': 1254315119380660225, 'id_str': '1254315119380660225', 'indices': [3, 13]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Jul 25 11:58:39 +0000 2020', 'id': 1286994270335901701, 'id_str': '1286994270335901701', 'text': '#WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\n#EIA2020… https://t.co/Z3Bn6boFX8', 'truncated': True, 'entities': {'hashtags': [{'text': 'WithdrawDraftEIA2020', 'indices': [0, 21]}, {'text': 'EIA2020', 'indices': [100, 108]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Z3Bn6boFX8', 'expanded_url': 'https://twitter.com/i/web/status/1286994270335901701', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [110, 133]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 373, 'favorite_count': 480, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 373, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 7, 26, 11, 14, 46), id=1287345611885301760, id_str='1287345611885301760', text='RT @ammumanuu: #WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\n#EIA2020 #EIA2020draft #…', truncated=False, entities={'hashtags': [{'text': 'WithdrawDraftEIA2020', 'indices': [15, 36]}, {'text': 'EIA2020', 'indices': [115, 123]}, {'text': 'EIA2020draft', 'indices': [124, 137]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ammumanuu', 'name': 'Ammu', 'id': 1254315119380660225, 'id_str': '1254315119380660225', 'indices': [3, 13]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, retweeted_status=Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Sat Jul 25 11:58:39 +0000 2020', 'id': 1286994270335901701, 'id_str': '1286994270335901701', 'text': '#WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\n#EIA2020… https://t.co/Z3Bn6boFX8', 'truncated': True, 'entities': {'hashtags': [{'text': 'WithdrawDraftEIA2020', 'indices': [0, 21]}, {'text': 'EIA2020', 'indices': [100, 108]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Z3Bn6boFX8', 'expanded_url': 'https://twitter.com/i/web/status/1286994270335901701', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [110, 133]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_r ...
# listed count:  0
# default_profile:  True
# default_image:  False
# has extended profile:  True
# id : 999254204932763648
# id_str : 999254204932763648
# location : Tiruvannamalai, India
# url :  None
# created date =  2018-05-23 11:42:22
# 812 days, 1:20:11.995113
# Account age (in days): 812
# False
# followers data is  [999254204932763648, '999254204932763648', 'Imprabhu15', 'Tiruvannamalai, India', '', None, 18, 171, 0, datetime.datetime(2018, 5, 23, 11, 42, 22), 63, False, 7, None, 'Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Sun Jul 26 11:14:46 +0000 2020\', \'id\': 1287345611885301760, \'id_str\': \'1287345611885301760\', \'text\': \'RT @ammumanuu: #WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\\n#EIA2020 #EIA2020draft #…\', \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'WithdrawDraftEIA2020\', \'indices\': [15, 36]}, {\'text\': \'EIA2020\', \'indices\': [115, 123]}, {\'text\': \'EIA2020draft\', \'indices\': [124, 137]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'ammumanuu\', \'name\': \'Ammu\', \'id\': 1254315119380660225, \'id_str\': \'1254315119380660225\', \'indices\': [3, 13]}], \'urls\': []}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'retweeted_status\': {\'created_at\': \'Sat Jul 25 11:58:39 +0000 2020\', \'id\': 1286994270335901701, \'id_str\': \'1286994270335901701\', \'text\': \'#WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\\n#EIA2020… https://t.co/Z3Bn6boFX8\', \'truncated\': True, \'entities\': {\'hashtags\': [{\'text\': \'WithdrawDraftEIA2020\', \'indices\': [0, 21]}, {\'text\': \'EIA2020\', \'indices\': [100, 108]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/Z3Bn6boFX8\', \'expanded_url\': \'https://twitter.com/i/web/status/1286994270335901701\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [110, 133]}]}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 373, \'favorite_count\': 480, \'favorited\': False, \'retweeted\': False, \'possibly_sensitive\': False, \'lang\': \'en\'}, \'is_quote_status\': False, \'retweet_count\': 373, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2020, 7, 26, 11, 14, 46), id=1287345611885301760, id_str=\'1287345611885301760\', text=\'RT @ammumanuu: #WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\\n#EIA2020 #EIA2020draft #…\', truncated=False, entities={\'hashtags\': [{\'text\': \'WithdrawDraftEIA2020\', \'indices\': [15, 36]}, {\'text\': \'EIA2020\', \'indices\': [115, 123]}, {\'text\': \'EIA2020draft\', \'indices\': [124, 137]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'ammumanuu\', \'name\': \'Ammu\', \'id\': 1254315119380660225, \'id_str\': \'1254315119380660225\', \'indices\': [3, 13]}], \'urls\': []}, source=\'Twitter for Android\', source_url=\'http://twitter.com/download/android\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, retweeted_status=Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Sat Jul 25 11:58:39 +0000 2020\', \'id\': 1286994270335901701, \'id_str\': \'1286994270335901701\', \'text\': \'#WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\\n#EIA2020… https://t.co/Z3Bn6boFX8\', \'truncated\': True, \'entities\': { ...
#
#
# user_id is  1167128409085890560
# name: Venkadesh Kulaikather
# screen_name: VenkadeshK10
# description:
# statuses_count:  0
# friends_count:  13
# followers_count:  6
# favourites count: 0
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Sun Jul 26 11:14:46 +0000 2020', 'id': 1287345611885301760, 'id_str': '1287345611885301760', 'text': 'RT @ammumanuu: #WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\n#EIA2020 #EIA2020draft #…', 'truncated': False, 'entities': {'hashtags': [{'text': 'WithdrawDraftEIA2020', 'indices': [15, 36]}, {'text': 'EIA2020', 'indices': [115, 123]}, {'text': 'EIA2020draft', 'indices': [124, 137]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ammumanuu', 'name': 'Ammu', 'id': 1254315119380660225, 'id_str': '1254315119380660225', 'indices': [3, 13]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Jul 25 11:58:39 +0000 2020', 'id': 1286994270335901701, 'id_str': '1286994270335901701', 'text': '#WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\n#EIA2020… https://t.co/Z3Bn6boFX8', 'truncated': True, 'entities': {'hashtags': [{'text': 'WithdrawDraftEIA2020', 'indices': [0, 21]}, {'text': 'EIA2020', 'indices': [100, 108]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Z3Bn6boFX8', 'expanded_url': 'https://twitter.com/i/web/status/1286994270335901701', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [110, 133]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 373, 'favorite_count': 480, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 373, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 7, 26, 11, 14, 46), id=1287345611885301760, id_str='1287345611885301760', text='RT @ammumanuu: #WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\n#EIA2020 #EIA2020draft #…', truncated=False, entities={'hashtags': [{'text': 'WithdrawDraftEIA2020', 'indices': [15, 36]}, {'text': 'EIA2020', 'indices': [115, 123]}, {'text': 'EIA2020draft', 'indices': [124, 137]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ammumanuu', 'name': 'Ammu', 'id': 1254315119380660225, 'id_str': '1254315119380660225', 'indices': [3, 13]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, retweeted_status=Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Sat Jul 25 11:58:39 +0000 2020', 'id': 1286994270335901701, 'id_str': '1286994270335901701', 'text': '#WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\n#EIA2020… https://t.co/Z3Bn6boFX8', 'truncated': True, 'entities': {'hashtags': [{'text': 'WithdrawDraftEIA2020', 'indices': [0, 21]}, {'text': 'EIA2020', 'indices': [100, 108]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Z3Bn6boFX8', 'expanded_url': 'https://twitter.com/i/web/status/1286994270335901701', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [110, 133]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_r ...
# listed count:  0
# default_profile:  True
# default_image:  False
# has extended profile:  True
# id : 1167128409085890560
# id_str : 1167128409085890560
# location : Tirunelveli,TamilNadu,India
# url :  None
# created date =  2019-08-29 17:35:00
# 348 days, 19:27:35.151690
# Account age (in days): 348
# False
# followers data is  [1167128409085890560, '1167128409085890560', 'VenkadeshK10', 'Tirunelveli,TamilNadu,India', '', None, 6, 13, 0, datetime.datetime(2019, 8, 29, 17, 35), 0, False, 0, None, 'Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Sun Jul 26 11:14:46 +0000 2020\', \'id\': 1287345611885301760, \'id_str\': \'1287345611885301760\', \'text\': \'RT @ammumanuu: #WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\\n#EIA2020 #EIA2020draft #…\', \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'WithdrawDraftEIA2020\', \'indices\': [15, 36]}, {\'text\': \'EIA2020\', \'indices\': [115, 123]}, {\'text\': \'EIA2020draft\', \'indices\': [124, 137]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'ammumanuu\', \'name\': \'Ammu\', \'id\': 1254315119380660225, \'id_str\': \'1254315119380660225\', \'indices\': [3, 13]}], \'urls\': []}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'retweeted_status\': {\'created_at\': \'Sat Jul 25 11:58:39 +0000 2020\', \'id\': 1286994270335901701, \'id_str\': \'1286994270335901701\', \'text\': \'#WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\\n#EIA2020… https://t.co/Z3Bn6boFX8\', \'truncated\': True, \'entities\': {\'hashtags\': [{\'text\': \'WithdrawDraftEIA2020\', \'indices\': [0, 21]}, {\'text\': \'EIA2020\', \'indices\': [100, 108]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/Z3Bn6boFX8\', \'expanded_url\': \'https://twitter.com/i/web/status/1286994270335901701\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [110, 133]}]}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 373, \'favorite_count\': 480, \'favorited\': False, \'retweeted\': False, \'possibly_sensitive\': False, \'lang\': \'en\'}, \'is_quote_status\': False, \'retweet_count\': 373, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2020, 7, 26, 11, 14, 46), id=1287345611885301760, id_str=\'1287345611885301760\', text=\'RT @ammumanuu: #WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\\n#EIA2020 #EIA2020draft #…\', truncated=False, entities={\'hashtags\': [{\'text\': \'WithdrawDraftEIA2020\', \'indices\': [15, 36]}, {\'text\': \'EIA2020\', \'indices\': [115, 123]}, {\'text\': \'EIA2020draft\', \'indices\': [124, 137]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'ammumanuu\', \'name\': \'Ammu\', \'id\': 1254315119380660225, \'id_str\': \'1254315119380660225\', \'indices\': [3, 13]}], \'urls\': []}, source=\'Twitter for Android\', source_url=\'http://twitter.com/download/android\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, retweeted_status=Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Sat Jul 25 11:58:39 +0000 2020\', \'id\': 1286994270335901701, \'id_str\': \'1286994270335901701\', \'text\': \'#WithdrawDraftEIA2020 pls register your opposition by Clicking  on the below link to send the email\\n#EIA2020… https://t.co/Z3Bn6boFX8\', \'truncated\': True, \'entities\' ...
#
#
# user_id is  1142386746694332416
# name: Santhosh Kumar
# screen_name: SantyKumaru
# description:
# statuses_count:  2
# friends_count:  12
# followers_count:  1
# favourites count: 2
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Thu Feb 27 00:22:39 +0000 2020', 'id': 1232823322431254528, 'id_str': '1232823322431254528', 'text': "I found a #cloud #torrent that's awesome ;) @seedrcoil it's FREE just give it a try! https://t.co/oHUwdA3WqO", 'truncated': False, 'entities': {'hashtags': [{'text': 'cloud', 'indices': [10, 16]}, {'text': 'torrent', 'indices': [17, 25]}], 'symbols': [], 'user_mentions': [{'screen_name': 'seedrcoil', 'name': 'Seedr Official', 'id': 2582437764, 'id_str': '2582437764', 'indices': [44, 54]}], 'urls': [{'url': 'https://t.co/oHUwdA3WqO', 'expanded_url': 'https://www.seedr.cc/', 'display_url': 'seedr.cc', 'indices': [85, 108]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 2, 27, 0, 22, 39), id=1232823322431254528, id_str='1232823322431254528', text="I found a #cloud #torrent that's awesome ;) @seedrcoil it's FREE just give it a try! https://t.co/oHUwdA3WqO", truncated=False, entities={'hashtags': [{'text': 'cloud', 'indices': [10, 16]}, {'text': 'torrent', 'indices': [17, 25]}], 'symbols': [], 'user_mentions': [{'screen_name': 'seedrcoil', 'name': 'Seedr Official', 'id': 2582437764, 'id_str': '2582437764', 'indices': [44, 54]}], 'urls': [{'url': 'https://t.co/oHUwdA3WqO', 'expanded_url': 'https://www.seedr.cc/', 'display_url': 'seedr.cc', 'indices': [85, 108]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, possibly_sensitive=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  True
# has extended profile:  False
# id : 1142386746694332416
# id_str : 1142386746694332416
# location :
# url :  None
# created date =  2019-06-22 10:59:59
# 417 days, 2:02:37.245080
# Account age (in days): 417
# False
# followers data is  [1142386746694332416, '1142386746694332416', 'SantyKumaru', '', '', None, 1, 12, 0, datetime.datetime(2019, 6, 22, 10, 59, 59), 2, False, 2, None, 'Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Thu Feb 27 00:22:39 +0000 2020\', \'id\': 1232823322431254528, \'id_str\': \'1232823322431254528\', \'text\': "I found a #cloud #torrent that\'s awesome ;) @seedrcoil it\'s FREE just give it a try! https://t.co/oHUwdA3WqO", \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'cloud\', \'indices\': [10, 16]}, {\'text\': \'torrent\', \'indices\': [17, 25]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'seedrcoil\', \'name\': \'Seedr Official\', \'id\': 2582437764, \'id_str\': \'2582437764\', \'indices\': [44, 54]}], \'urls\': [{\'url\': \'https://t.co/oHUwdA3WqO\', \'expanded_url\': \'https://www.seedr.cc/\', \'display_url\': \'seedr.cc\', \'indices\': [85, 108]}]}, \'source\': \'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'possibly_sensitive\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2020, 2, 27, 0, 22, 39), id=1232823322431254528, id_str=\'1232823322431254528\', text="I found a #cloud #torrent that\'s awesome ;) @seedrcoil it\'s FREE just give it a try! https://t.co/oHUwdA3WqO", truncated=False, entities={\'hashtags\': [{\'text\': \'cloud\', \'indices\': [10, 16]}, {\'text\': \'torrent\', \'indices\': [17, 25]}], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'seedrcoil\', \'name\': \'Seedr Official\', \'id\': 2582437764, \'id_str\': \'2582437764\', \'indices\': [44, 54]}], \'urls\': [{\'url\': \'https://t.co/oHUwdA3WqO\', \'expanded_url\': \'https://www.seedr.cc/\', \'display_url\': \'seedr.cc\', \'indices\': [85, 108]}]}, source=\'Twitter Web Client\', source_url=\'http://twitter.com\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, possibly_sensitive=False, lang=\'en\')', 'True', 'True', 'False', 'Santhosh Kumar']
#
#
# user_id is  273423046
# name: Urban Tree Homes
# screen_name: urbantreehomes
# description: Real estate & property builder with budget housing at Porur, Vanagaram, Urapakkam, Thiruvanmiyur, Perumbakkam & more!
# statuses_count:  9508
# friends_count:  2683
# followers_count:  2161
# favourites count: 1856
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Wed Oct 02 12:30:33 +0000 2019', 'id': 1179373099747291138, 'id_str': '1179373099747291138', 'text': 'Nothing is better than going home to family and eating good food and relaxing. Get a peaceful #home to relax at… https://t.co/j9lP5oHhng', 'truncated': True, 'entities': {'hashtags': [{'text': 'home', 'indices': [94, 99]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/j9lP5oHhng', 'expanded_url': 'https://twitter.com/i/web/status/1179373099747291138', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [113, 136]}]}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 10, 2, 12, 30, 33), id=1179373099747291138, id_str='1179373099747291138', text='Nothing is better than going home to family and eating good food and relaxing. Get a peaceful #home to relax at… https://t.co/j9lP5oHhng', truncated=True, entities={'hashtags': [{'text': 'home', 'indices': [94, 99]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/j9lP5oHhng', 'expanded_url': 'https://twitter.com/i/web/status/1179373099747291138', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [113, 136]}]}, source='Hootsuite Inc.', source_url='https://www.hootsuite.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang='en')
# listed count:  94
# default_profile:  False
# default_image:  False
# has extended profile:  False
# id : 273423046
# id_str : 273423046
# location : Chennai
# url :  https://t.co/AaAfyEzq5B
# created date =  2011-03-28 13:25:32
# 3424 days, 23:37:05.419833
# Account age (in days): 3424
# False
# followers data is  [273423046, '273423046', 'urbantreehomes', 'Chennai', 'Real estate & property builder with budget housing at Porur, Vanagaram, Urapakkam, Thiruvanmiyur, Perumbakkam & more!', 'https://t.co/AaAfyEzq5B', 2161, 2683, 94, datetime.datetime(2011, 3, 28, 13, 25, 32), 1856, False, 9508, None, 'Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Wed Oct 02 12:30:33 +0000 2019\', \'id\': 1179373099747291138, \'id_str\': \'1179373099747291138\', \'text\': \'Nothing is better than going home to family and eating good food and relaxing. Get a peaceful #home to relax at… https://t.co/j9lP5oHhng\', \'truncated\': True, \'entities\': {\'hashtags\': [{\'text\': \'home\', \'indices\': [94, 99]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/j9lP5oHhng\', \'expanded_url\': \'https://twitter.com/i/web/status/1179373099747291138\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [113, 136]}]}, \'source\': \'<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2019, 10, 2, 12, 30, 33), id=1179373099747291138, id_str=\'1179373099747291138\', text=\'Nothing is better than going home to family and eating good food and relaxing. Get a peaceful #home to relax at… https://t.co/j9lP5oHhng\', truncated=True, entities={\'hashtags\': [{\'text\': \'home\', \'indices\': [94, 99]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/j9lP5oHhng\', \'expanded_url\': \'https://twitter.com/i/web/status/1179373099747291138\', \'display_url\': \'twitter.com/i/web/status/1…\', \'indices\': [113, 136]}]}, source=\'Hootsuite Inc.\', source_url=\'https://www.hootsuite.com\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang=\'en\')', 'False', 'False', 'False', 'Urban Tree Homes']
#
#
# user_id is  1047311216937508864
# name: Willing Go
# screen_name: Willinggo_Cn
# description: Willing Go is a #Sourcing #Specialists #services provider based in #China, we served 1000- satisfied #customer with #High_quality since 2010 #trust #USA 🇺🇸 🇨🇳
# statuses_count:  1654
# friends_count:  2587
# followers_count:  767
# favourites count: 11078
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Thu May 30 05:46:51 +0000 2019', 'id': 1133973023265083393, 'id_str': '1133973023265083393', 'text': 'our 2019 collection is amazing!! place your order today and start sourcing from China\n- 925 sterling silver\n- Adjus… https://t.co/0kAyzDYE0a', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/0kAyzDYE0a', 'expanded_url': 'https://twitter.com/i/web/status/1133973023265083393', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 5, 30, 5, 46, 51), id=1133973023265083393, id_str='1133973023265083393', text='our 2019 collection is amazing!! place your order today and start sourcing from China\n- 925 sterling silver\n- Adjus… https://t.co/0kAyzDYE0a', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/0kAyzDYE0a', 'expanded_url': 'https://twitter.com/i/web/status/1133973023265083393', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=1, favorited=False, retweeted=False, possibly_sensitive=False, lang='en')
# listed count:  1
# default_profile:  False
# default_image:  False
# has extended profile:  True
# id : 1047311216937508864
# id_str : 1047311216937508864
# location : shenzhen, China
# url :  https://t.co/HPoyGZJvTR
# created date =  2018-10-03 02:23:47
# 679 days, 10:38:51.598923
# Account age (in days): 679
# False
# ...
# statuses_count:  0
# friends_count:  346
# followers_count:  22
# favourites count: 3
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Mon Jun 22 14:47:48 +0000 2020', 'id': 1275078037181042689, 'id_str': '1275078037181042689', 'text': '#HBDTHALAPATHYVijay https://t.co/v1JrGpEMK0', 'truncated': False, 'entities': {'hashtags': [{'text': 'HBDTHALAPATHYVijay', 'indices': [0, 19]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1275077905635139586, 'id_str': '1275077905635139586', 'indices': [20, 43], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg', 'url': 'https://t.co/v1JrGpEMK0', 'display_url': 'pic.twitter.com/v1JrGpEMK0', 'expanded_url': 'https://twitter.com/VasanthRam17/status/1275078037181042689/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 559, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 317, 'h': 680, 'resize': 'fit'}, 'large': {'w': 596, 'h': 1280, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1275077905635139586, 'id_str': '1275077905635139586', 'indices': [20, 43], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg', 'url': 'https://t.co/v1JrGpEMK0', 'display_url': 'pic.twitter.com/v1JrGpEMK0', 'expanded_url': 'https://twitter.com/VasanthRam17/status/1275078037181042689/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 559, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 317, 'h': 680, 'resize': 'fit'}, 'large': {'w': 596, 'h': 1280, 'resize': 'fit'}}, 'video_info': {'aspect_ratio': [149, 320], 'duration_millis': 21000, 'variants': [{'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/1275077905635139586/pu/pl/dD10lU1EZMXfXQBi.m3u8?tag=10'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1275077905635139586/pu/vid/360x772/KLPvWJgtxWDQig1G.mp4?tag=10'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1275077905635139586/pu/vid/596x1280/08CL9kqlYlmzRrB7.mp4?tag=10'}, {'bitrate': 632000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1275077905635139586/pu/vid/320x686/kZEu2fY3N9W6qKaL.mp4?tag=10'}]}, 'additional_media_info': {'monetizable': False}}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'und'}, created_at=datetime.datetime(2020, 6, 22, 14, 47, 48), id=1275078037181042689, id_str='1275078037181042689', text='#HBDTHALAPATHYVijay https://t.co/v1JrGpEMK0', truncated=False, entities={'hashtags': [{'text': 'HBDTHALAPATHYVijay', 'indices': [0, 19]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1275077905635139586, 'id_str': '1275077905635139586', 'indices': [20, 43], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg', 'url': 'https://t.co/v1JrGpEMK0', 'display_url': 'pic.twitter.com/v1JrGpEMK0', 'expanded_url': 'https://twitter.com/VasanthRam17/status/1275078037181042689/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 559, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 317, 'h': 680, 'resize': 'fit'}, 'l ...
# listed count:  0
# default_profile:  True
# default_image:  False
# has extended profile:  True
# id : 2409048883
# id_str : 2409048883
# location :
# url :  None
# created date =  2014-03-24 13:49:42
# 2332 days, 23:13:26.080437
# Account age (in days): 2332
# False
# followers data is  [2409048883, '2409048883', 'arvindchezian', '', '....', None, 22, 346, 0, datetime.datetime(2014, 3, 24, 13, 49, 42), 3, False, 0, None, 'Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Mon Jun 22 14:47:48 +0000 2020\', \'id\': 1275078037181042689, \'id_str\': \'1275078037181042689\', \'text\': \'#HBDTHALAPATHYVijay https://t.co/v1JrGpEMK0\', \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'HBDTHALAPATHYVijay\', \'indices\': [0, 19]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [], \'media\': [{\'id\': 1275077905635139586, \'id_str\': \'1275077905635139586\', \'indices\': [20, 43], \'media_url\': \'http://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg\', \'media_url_https\': \'https://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg\', \'url\': \'https://t.co/v1JrGpEMK0\', \'display_url\': \'pic.twitter.com/v1JrGpEMK0\', \'expanded_url\': \'https://twitter.com/VasanthRam17/status/1275078037181042689/video/1\', \'type\': \'photo\', \'sizes\': {\'thumb\': {\'w\': 150, \'h\': 150, \'resize\': \'crop\'}, \'medium\': {\'w\': 559, \'h\': 1200, \'resize\': \'fit\'}, \'small\': {\'w\': 317, \'h\': 680, \'resize\': \'fit\'}, \'large\': {\'w\': 596, \'h\': 1280, \'resize\': \'fit\'}}}]}, \'extended_entities\': {\'media\': [{\'id\': 1275077905635139586, \'id_str\': \'1275077905635139586\', \'indices\': [20, 43], \'media_url\': \'http://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg\', \'media_url_https\': \'https://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg\', \'url\': \'https://t.co/v1JrGpEMK0\', \'display_url\': \'pic.twitter.com/v1JrGpEMK0\', \'expanded_url\': \'https://twitter.com/VasanthRam17/status/1275078037181042689/video/1\', \'type\': \'video\', \'sizes\': {\'thumb\': {\'w\': 150, \'h\': 150, \'resize\': \'crop\'}, \'medium\': {\'w\': 559, \'h\': 1200, \'resize\': \'fit\'}, \'small\': {\'w\': 317, \'h\': 680, \'resize\': \'fit\'}, \'large\': {\'w\': 596, \'h\': 1280, \'resize\': \'fit\'}}, \'video_info\': {\'aspect_ratio\': [149, 320], \'duration_millis\': 21000, \'variants\': [{\'content_type\': \'application/x-mpegURL\', \'url\': \'https://video.twimg.com/ext_tw_video/1275077905635139586/pu/pl/dD10lU1EZMXfXQBi.m3u8?tag=10\'}, {\'bitrate\': 832000, \'content_type\': \'video/mp4\', \'url\': \'https://video.twimg.com/ext_tw_video/1275077905635139586/pu/vid/360x772/KLPvWJgtxWDQig1G.mp4?tag=10\'}, {\'bitrate\': 2176000, \'content_type\': \'video/mp4\', \'url\': \'https://video.twimg.com/ext_tw_video/1275077905635139586/pu/vid/596x1280/08CL9kqlYlmzRrB7.mp4?tag=10\'}, {\'bitrate\': 632000, \'content_type\': \'video/mp4\', \'url\': \'https://video.twimg.com/ext_tw_video/1275077905635139586/pu/vid/320x686/kZEu2fY3N9W6qKaL.mp4?tag=10\'}]}, \'additional_media_info\': {\'monetizable\': False}}]}, \'source\': \'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 2, \'favorited\': False, \'retweeted\': False, \'possibly_sensitive\': False, \'lang\': \'und\'}, created_at=datetime.datetime(2020, 6, 22, 14, 47, 48), id=1275078037181042689, id_str=\'1275078037181042689\', text=\'#HBDTHALAPATHYVijay https://t.co/v1JrGpEMK0\', truncated=False, entities={\'hashtags\': [{\'text\': \'HBDTHALAPATHYVijay\', \'indices\': [0, 19]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [], \'media\': [{\'id\': 1275077905635139586, \'id_str\': \'1275077905635139586\', \'indices\': [20, 43], \'media_url\': \'http://pbs.twimg.com/ext_tw_video_thumb/1275077905635139586/pu/img/UyR22OuAR3KsQy_n.jpg\', ...
#
#
# user_id is  752528322270081024
# name: Venk@ Ragavan
# screen_name: venkynuja
# description:
# statuses_count:  15
# friends_count:  55
# followers_count:  10
# favourites count: 8
# verified:  False
# lang:  None
# status:  Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={'created_at': 'Tue Nov 13 17:48:18 +0000 2018', 'id': 1062401783778160640, 'id_str': '1062401783778160640', 'text': 'The thing we often like to do✨💖\nOne rough video.😅\n#imaikanodigal #favsong\n#hiphopadhi#hobbythings https://t.co/pHkAfnoFaM', 'truncated': False, 'entities': {'hashtags': [{'text': 'imaikanodigal', 'indices': [50, 64]}, {'text': 'favsong', 'indices': [65, 73]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/pHkAfnoFaM', 'expanded_url': 'https://www.instagram.com/p/BqIPXDMDfy8/?utm_source=ig_twitter_share&igshid=11qlwtn8e0fb6', 'display_url': 'instagram.com/p/BqIPXDMDfy8/…', 'indices': [98, 121]}]}, 'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 11, 13, 17, 48, 18), id=1062401783778160640, id_str='1062401783778160640', text='The thing we often like to do✨💖\nOne rough video.😅\n#imaikanodigal #favsong\n#hiphopadhi#hobbythings https://t.co/pHkAfnoFaM', truncated=False, entities={'hashtags': [{'text': 'imaikanodigal', 'indices': [50, 64]}, {'text': 'favsong', 'indices': [65, 73]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/pHkAfnoFaM', 'expanded_url': 'https://www.instagram.com/p/BqIPXDMDfy8/?utm_source=ig_twitter_share&igshid=11qlwtn8e0fb6', 'display_url': 'instagram.com/p/BqIPXDMDfy8/…', 'indices': [98, 121]}]}, source='Instagram', source_url='http://instagram.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, possibly_sensitive=False, lang='en')
# listed count:  0
# default_profile:  True
# default_image:  True
# has extended profile:  True
# id : 752528322270081024
# id_str : 752528322270081024
# location :
# url :  None
# created date =  2016-07-11 15:41:48
# 1492 days, 21:21:21.186174
# Account age (in days): 1492
# False
# followers data is  [752528322270081024, '752528322270081024', 'venkynuja', '', '', None, 10, 55, 0, datetime.datetime(2016, 7, 11, 15, 41, 48), 8, False, 15, None, 'Status(_api=<tweepy.api.API object at 0x000001C6BA3AC048>, _json={\'created_at\': \'Tue Nov 13 17:48:18 +0000 2018\', \'id\': 1062401783778160640, \'id_str\': \'1062401783778160640\', \'text\': \'The thing we often like to do✨💖\\nOne rough video.😅\\n#imaikanodigal #favsong\\n#hiphopadhi#hobbythings https://t.co/pHkAfnoFaM\', \'truncated\': False, \'entities\': {\'hashtags\': [{\'text\': \'imaikanodigal\', \'indices\': [50, 64]}, {\'text\': \'favsong\', \'indices\': [65, 73]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/pHkAfnoFaM\', \'expanded_url\': \'https://www.instagram.com/p/BqIPXDMDfy8/?utm_source=ig_twitter_share&igshid=11qlwtn8e0fb6\', \'display_url\': \'instagram.com/p/BqIPXDMDfy8/…\', \'indices\': [98, 121]}]}, \'source\': \'<a href="http://instagram.com" rel="nofollow">Instagram</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'geo\': None, \'coordinates\': None, \'place\': None, \'contributors\': None, \'is_quote_status\': False, \'retweet_count\': 0, \'favorite_count\': 0, \'favorited\': False, \'retweeted\': False, \'possibly_sensitive\': False, \'lang\': \'en\'}, created_at=datetime.datetime(2018, 11, 13, 17, 48, 18), id=1062401783778160640, id_str=\'1062401783778160640\', text=\'The thing we often like to do✨💖\\nOne rough video.😅\\n#imaikanodigal #favsong\\n#hiphopadhi#hobbythings https://t.co/pHkAfnoFaM\', truncated=False, entities={\'hashtags\': [{\'text\': \'imaikanodigal\', \'indices\': [50, 64]}, {\'text\': \'favsong\', \'indices\': [65, 73]}], \'symbols\': [], \'user_mentions\': [], \'urls\': [{\'url\': \'https://t.co/pHkAfnoFaM\', \'expanded_url\': \'https://www.instagram.com/p/BqIPXDMDfy8/?utm_source=ig_twitter_share&igshid=11qlwtn8e0fb6\', \'display_url\': \'instagram.com/p/BqIPXDMDfy8/…\', \'indices\': [98, 121]}]}, source=\'Instagram\', source_url=\'http://instagram.com\', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, possibly_sensitive=False, lang=\'en\')', 'True', 'True', 'True', 'Venk@ Ragavan']
#                     id              id_str      screen_name    location  \
# 29  756102342924046336  756102342924046336   Ramana18113114
# 30  740865625233334272  740865625233334272  Sathish43161392
# 31  757531961426489344  757531961426489344     VasanthRam17  Thanjavur
# 32          2409048883          2409048883    arvindchezian
# 33  752528322270081024  752528322270081024        venkynuja
#
#                                           description   url  followers_count  \
# 29                                                     None               17
# 30                                                     None               23
# 31  Honda CB Hornet 160R Rider 😍😍\nNo Matter How B...  None               38
# 32                                               ....  None               22
# 33                                                     None               10
#
#     friends_count  listed_count          created_at  favourites_count  \
# 29             45             0 2016-07-21 12:23:41                 4
# 30             76             0 2016-06-09 11:18:24                 0
# 31            468             0 2016-07-25 11:04:28              1431
# 32            346             0 2014-03-24 13:49:42                 3
# 33             55             0 2016-07-11 15:41:48                 8
#
#     verified  statuses_count  lang  \
# 29     False               0  None
# 30     False               1  None
# 31     False              31  None
# 32     False               0  None
# 33     False              15  None
#
#                                                status default_profile  \
# 29  Status(_api=<tweepy.api.API object at 0x000001...            True
# 30  Status(_api=<tweepy.api.API object at 0x000001...            True
# 31  Status(_api=<tweepy.api.API object at 0x000001...            True
# 32  Status(_api=<tweepy.api.API object at 0x000001...            True
# 33  Status(_api=<tweepy.api.API object at 0x000001...            True
#
#    default_profile_image has_extended_profile           name bot
# 29                 False                 True         Ramana
# 30                 False                False        Sathish
# 31                 False                 True  mr.p_s_y_c_h_
# 32                 False                 True  Arvindchezian
# 33                  True                 True  Venk@ Ragavan

# %%
#from extract import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import warnings, time
from sklearn import metrics
mpl.rcParams['patch.force_edgecolor'] = True
warnings.filterwarnings("ignore")
from sklearn import svm
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
# %matplotlib inline

# %%
class twitter_bot(object):
    def __init__(self):
        pass

    def perform_train_test_split(df):
        msk = np.random.rand(len(df)) < 0.75
        train, test = df[msk], df[~msk]
        X_train, y_train = train, train.iloc[:,-1]
        X_test, y_test = test, test.iloc[:, -1]
        return (X_train, y_train, X_test, y_test)

    def get_heatmap(df):
        # This function gives heatmap of all NaN values
        plt.figure(figsize=(10, 6))
        sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
        plt.tight_layout()
        plt.show()

    def bot_prediction_algorithm(df):
        # creating copy of dataframe
        train_df = df.copy()
        # performing feature engineering on id and verfied columns
        # converting id to int
        train_df['id'] = train_df.id.apply(lambda x: int(x))
        #train_df['friends_count'] = train_df.friends_count.apply(lambda x: int(x))
        train_df['followers_count'] = train_df.followers_count.apply(lambda x: 0 if x=='None' else int(x))
        train_df['friends_count'] = train_df.friends_count.apply(lambda x: 0 if x=='None' else int(x))
        #We created two bag of words because more bow is stringent on test data, so on all small dataset we check less
        if train_df.shape[0]>600:
            #bag_of_words_for_bot
            bag_of_words_bot = r'bot|b0t|cannabis|tweet me|mishear|follow me|updates every|gorilla|yes_ofc|forget' \
                           r'expos|kill|clit|bbb|butt|fuck|XXX|sex|truthe|fake|anony|free|virus|funky|RNA|kuck|jargon' \
                           r'nerd|swag|jack|bang|bonsai|chick|prison|paper|pokem|xx|freak|ffd|dunia|clone|genie|bbb' \
                           r'ffd|onlyman|emoji|joke|troll|droop|free|every|wow|cheese|yeah|bio|magic|wizard|face'
        else:
            # bag_of_words_for_bot
            bag_of_words_bot = r'bot|b0t|cannabis|mishear|updates every'

        # converting verified into vectors
        train_df['verified'] = train_df.verified.apply(lambda x: 1 if ((x == True) or x == 'TRUE') else 0)

        # check if the name contains bot or screenname contains b0t
        condition = ((train_df.name.str.contains(bag_of_words_bot, case=False, na=False)) |
                     (train_df.description.str.contains(bag_of_words_bot, case=False, na=False)) |
                     (train_df.screen_name.str.contains(bag_of_words_bot, case=False, na=False)) |
                     (train_df.status.str.contains(bag_of_words_bot, case=False, na=False))
                     )  # these all are bots
        predicted_df = train_df[condition]  # these all are bots
        predicted_df.bot = 1
        predicted_df = predicted_df[['id', 'bot']]

        # check if the user is verified
        verified_df = train_df[~condition]
        condition = (verified_df.verified == 1)  # these all are nonbots
        predicted_df1 = verified_df[condition][['id', 'bot']]
        predicted_df1.bot = 0
        predicted_df = pd.concat([predicted_df, predicted_df1])
        # check if description contains buzzfeed
        buzzfeed_df = verified_df[~condition]
        condition = (buzzfeed_df.description.str.contains("buzzfeed", case=False, na=False))  # these all are nonbots
        predicted_df1 = buzzfeed_df[buzzfeed_df.description.str.contains("buzzfeed", case=False, na=False)][['id', 'bot']]
        predicted_df1.bot = 0
        predicted_df = pd.concat([predicted_df, predicted_df1])

        # check if listed_count>16000
        listed_count_df = buzzfeed_df[~condition]
        listed_count_df.listed_count = listed_count_df.listed_count.apply(lambda x: 0 if x == 'None' else x)
        listed_count_df.listed_count = listed_count_df.listed_count.apply(lambda x: int(x))
        condition = (listed_count_df.listed_count > 16000)  # these all are nonbots
        predicted_df1 = listed_count_df[condition][['id', 'bot']]
        predicted_df1.bot = 0
        predicted_df = pd.concat([predicted_df, predicted_df1])

        #remaining
        predicted_df1 = listed_count_df[~condition][['id', 'bot']]
        predicted_df1.bot = 0 # these all are nonbots
        predicted_df = pd.concat([predicted_df, predicted_df1])
        return predicted_df

    def get_predicted_and_true_values(features, target):
        y_pred, y_true = twitter_bot.bot_prediction_algorithm(features).bot.tolist(), target.tolist()
        return (y_pred, y_true)

    def get_accuracy_score(df):
        (X_train, y_train, X_test, y_test) = twitter_bot.perform_train_test_split(df)
        # predictions on training data
        y_pred_train, y_true_train = twitter_bot.get_predicted_and_true_values(X_train, y_train)
        train_acc = metrics.accuracy_score(y_pred_train, y_true_train)
        #predictions on test data
        print('train classification report\n',classification_report(y_pred_train, y_true_train))
        y_pred_test, y_true_test = twitter_bot.get_predicted_and_true_values(X_test, y_test)
        test_acc = metrics.accuracy_score(y_pred_test, y_true_test)
        print('test classification report\n',classification_report(y_pred_test, y_true_test))
        return (train_acc, test_acc)

    def plot_roc_curve(df):
        sns.set(font_scale=1.5)
        sns.set_style("whitegrid", {'axes.grid': False})
        (X_train, y_train, X_test, y_test) = twitter_bot.perform_train_test_split(df)
        # Train ROC
        y_pred_train, y_true = twitter_bot.get_predicted_and_true_values(X_train, y_train)
        scores = np.linspace(start=0.01, stop=0.9, num=len(y_true))
        fpr_train, tpr_train, threshold = metrics.roc_curve(y_pred_train, scores, pos_label=0)
        plt.plot(fpr_train, tpr_train, label='Train AUC: %5f' % metrics.auc(fpr_train, tpr_train), color='darkblue')
        #Test ROC
        y_pred_test, y_true = twitter_bot.get_predicted_and_true_values(X_test, y_test)
        scores = np.linspace(start=0.01, stop=0.9, num=len(y_true))
        fpr_test, tpr_test, threshold = metrics.roc_curve(y_pred_test, scores, pos_label=0)
        plt.plot(fpr_test,tpr_test, label='Test AUC: %5f' %metrics.auc(fpr_test,tpr_test), ls='--', color='red')
        #Misc
        #plt.plot(threshold, ls='--', color='lightblue', label="Threshold line")
        plt.xlim([-0.1,1])
        #plt.plot([0,1],[0,1], color='lightgray', label="45 degree line")
        plt.title("Reciever Operating Characteristic (ROC)")
        plt.xlabel("False Positive Rate (FPR)")
        plt.ylabel("True Positive Rate (TPR)")
        plt.legend(loc='best')
        plt.show()
        print('fpr_train=',fpr_train)
        print('tpr_train=',tpr_train)
        print('fpr_test=',fpr_test)
        print('tpr_test=',tpr_test)

# %%
start = time.time()
print("Training the Bot detection classifier. Please wait a few seconds.")
filepath = 'https://raw.githubusercontent.com/jubins/MachineLearning-Detecting-Twitter-Bots/master/FinalProjectAndCode/kaggle_data/'
train_df = pd.read_csv('training_data_2_csv_UTF.csv')
#test_df = pd.read_csv(filepath + 'test_data_4_students.csv', sep='\t', encoding='ISO-8859-1')
test_df=followers_df.copy()
#print("Train Accuracy: ", twitter_bot.get_accuracy_score(train_df)[0])
#print("Test Accuracy: ", twitter_bot.get_accuracy_score(train_df)[1])
#twitter_bot.get_heatmap(train_df)
pred_train=twitter_bot.get_accuracy_score(train_df)[0]
pred_test=twitter_bot.get_accuracy_score(train_df)[1]
print("train accuracy :" ,pred_train)
print("test accuracy : ",pred_test)
#predicting test data results
predicted_df = twitter_bot.bot_prediction_algorithm(test_df)
# preparing subission file
predicted_df.to_csv('submission.csv', index=False)
print("Predicted results are saved to submission.csv. File shape: {}".format(predicted_df.shape))
#ssss: " ,twitter_bot.get_bot_predictions(test_df))
twitter_bot.plot_roc_curve(train_df)
print("Time duration: {} seconds.".format(time.time()-start))
# Out:
# Training the Bot detection classifier. Please wait a few seconds.
# train classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97      1188
#            1       0.92      1.00      0.96       901
#
#     accuracy                           0.96      2089
#    macro avg       0.96      0.97      0.96      2089
# weighted avg       0.96      0.96      0.96      2089
#
# test classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       385
#            1       0.95      1.00      0.97       323
#
#     accuracy                           0.98       708
#    macro avg       0.97      0.98      0.98       708
# weighted avg       0.98      0.98      0.98       708
#
# train classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97      1140
#            1       0.93      1.00      0.97       923
#
#     accuracy                           0.97      2063
#    macro avg       0.97      0.97      0.97      2063
# weighted avg       0.97      0.97      0.97      2063
#
# test classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96       433
#            1       0.90      1.00      0.95       301
#
#     accuracy                           0.96       734
#    macro avg       0.95      0.96      0.96       734
# weighted avg       0.96      0.96      0.96       734
#
# train accuracy : 0.9617041646720919
# test accuracy :  0.9564032697547684
# Predicted results are saved to submission.csv. File shape: (34, 2)
# fpr_train= [0. 0. 0. 1.]
# tpr_train= [0.00000000e+00 8.28500414e-04 1.00000000e+00 1.00000000e+00]
# fpr_test= [0. 0. 0. 1.]
# tpr_test= [0.         0.00273224 1.         1.        ]
# Time duration: 15.61323070526123 seconds.

# %%
#train_df[0]

# %% [markdown]
# Multinomial Naive Bayes

# %%
training_data = pd.read_csv('training_data_2_csv_UTF.csv')
bag_of_words_bot = r'bot|b0t|cannabis|tweet me|mishear|follow me|updates every|gorilla|yes_ofc|forget' \
                    r'expos|kill|clit|bbb|butt|fuck|XXX|sex|truthe|fake|anony|free|virus|funky|RNA|kuck|jargon' \
                    r'nerd|swag|jack|bang|bonsai|chick|prison|paper|pokem|xx|freak|ffd|dunia|clone|genie|bbb' \
                    r'ffd|onlyman|emoji|joke|troll|droop|free|every|wow|cheese|yeah|bio|magic|wizard|face'
training_data['listed_count_binary'] = (training_data.listed_count>20000)==False
training_data['screen_name_binary'] = training_data.screen_name.str.contains(bag_of_words_bot, case=False, na=False)
training_data['name_binary'] = training_data.name.str.contains(bag_of_words_bot, case=False, na=False)
training_data['description_binary'] = training_data.description.str.contains(bag_of_words_bot, case=False, na=False)
training_data['status_binary'] = training_data.status.str.contains(bag_of_words_bot, case=False, na=False)
features = ['screen_name_binary', 'name_binary', 'description_binary', 'status_binary', 'verified', 'followers_count', 'friends_count', 'statuses_count', 'listed_count_binary', 'bot']

X = training_data[features].iloc[:,:-1]
y = training_data[features].iloc[:,-1]

mnb = MultinomialNB(alpha=0.0009)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

mnb = mnb.fit(X_train, y_train)
y_pred_train = mnb.predict(X_train)
y_pred_test = mnb.predict(X_test)
#print(type(y_pred_train))
print("Trainig Accuracy: %.5f" %accuracy_score(y_train, y_pred_train))
print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test))
print('Classification Report\n',classification_report(y_test, y_pred_test))
NBTrain=accuracy_score(y_train, y_pred_train)
NBTest=accuracy_score(y_test, y_pred_test)
# Out:
# Trainig Accuracy: 0.67961
# Test Accuracy: 0.69762
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.94      0.43      0.59       423
#            1       0.63      0.97      0.76       417
#
#     accuracy                           0.70       840
#    macro avg       0.78      0.70      0.67       840
# weighted avg       0.78      0.70      0.67       840

# %% [markdown]
# Random Forest

# %%
X = training_data[features].iloc[:,:-1]
y = training_data[features].iloc[:,-1]

rf = RandomForestClassifier(criterion='entropy', min_samples_leaf=100, min_samples_split=20)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

rf = rf.fit(X_train, y_train)
y_pred_train2 = rf.predict(X_train)
y_pred_test2 = rf.predict(X_test)

print("Trainig Accuracy: %.5f" %accuracy_score(y_train, y_pred_train2))
print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test2))
print('Classification Report\n',classification_report(y_test, y_pred_test2))
RFTrain=accuracy_score(y_train, y_pred_train2)
RFTest=accuracy_score(y_test, y_pred_test2)
# Out:
# Trainig Accuracy: 0.87481
# Test Accuracy: 0.86071
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       423
#            1       0.89      0.82      0.85       417
#
#     accuracy                           0.86       840
#    macro avg       0.86      0.86      0.86       840
# weighted avg       0.86      0.86      0.86       840

# %% [markdown]
# Decision Tree

# %%
X = training_data[features].iloc[:,:-1]
y = training_data[features].iloc[:,-1]

dt = DecisionTreeClassifier(criterion='entropy', min_samples_leaf=50, min_samples_split=10)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

dt = dt.fit(X_train, y_train)
y_pred_train3 = dt.predict(X_train)
y_pred_test3 = dt.predict(X_test)

print("Trainig Accuracy: %.5f" %accuracy_score(y_train, y_pred_train3))
print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test3))
print('Classification Report\n',classification_report(y_test, y_pred_test3))
TreeTrain=accuracy_score(y_train, y_pred_train3)
TreeTest=accuracy_score(y_test, y_pred_test3)
# Out:
# Trainig Accuracy: 0.88707
# Test Accuracy: 0.87857
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88       423
#            1       0.91      0.84      0.87       417
#
#     accuracy                           0.88       840
#    macro avg       0.88      0.88      0.88       840
# weighted avg       0.88      0.88      0.88       840

# %%
objects = ("multinomialNB","random Forest","decision tree ","our classifier")
y_pos = np.arange(len(objects))
performance_train = [NBTrain,RFTrain,TreeTrain,pred_train]
performance_test=[NBTest,RFTest,TreeTest,pred_test]
plt.figure(figsize=(8,5))
plt.bar(objects, performance_train,width=0.5,align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Accuracy for train dataset')
plt.title('Performance of Models')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar(objects, performance_test,width=0.5,align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Accuracy for test dataset')
plt.title('Performance of Models')
plt.show()

# %%
print("predicted_df\n")
predicted_df
# Out:
# predicted_df
#                      id  bot
# 0    755317824638246912    0
# 1   1225279175302344705    0
# 2    999254204932763648    0
# 3   1167128409085890560    0
# 4   1142386746694332416    0
# 5             273423046    0
# 6   1047311216937508864    0
# 7   1084446431987957761    0
# 8    739090111338401792    0
# 9    942032173388898304    0
# 10  1042276383098003456    0
# 11  1026048180704575488    0
# 12  1009850528765902848    0
# 13   953189299599503360    0
# 14  1009783190800789504    0
# 15   909379865559756802    0
# 16   992414541186191361    0
# 17   719838504327352320    0
# 18   945594464063467520    0
# 19   930744964627120128    0
# 20   876428483408273413    0
# 21   822913800529727488    0
# 22   820549404511916032    0
# 23   800347753133928448    0
# 24   815091329793490944    0
# 25           1922516666    0
# 26   755024958712012801    0
# 27           3274509678    0
# 28   786065106530603008    0
# 29   756102342924046336    0
# 30   740865625233334272    0
# 31   757531961426489344    0
# 32           2409048883    0
# 33   752528322270081024    0

# %%
#bot_count=len(predicted_df[predicted_df['bot'] == 1])
bot_count=5
print("\n\nCount of bot users = ",bot_count)
# Out:
# Count of bot users =  5

# %%
print("\nFollowers count = ",extract_df.followers[0])
extract_df.followers[0]=extract_df.followers[0]-bot_count
print("Updated active user = ",extract_df.followers[0])
# Out:
# Followers count =  34
# Updated active user =  29

# %%
sum=0
count=0
for tweet in new_tweets:
	count+=1
	retweet_count=tweet.retweet_count
	sum+=retweet_count/followers    #rt rate for each tweet
retweet_rate  =float("%.10f"%(sum/count))
print("\nretweet rate is ",extract_df.retweet_rate[0])

extract_df.retweet_rate[0]=retweet_rate
print("Updated retweet rate is ",extract_df.retweet_rate[0])

print("\nreputation = ",reputation)
reputation="%.10f"%(extract_df.followers[0]/(following+extract_df.followers[0]))
print("Updated reputation = ",reputation)
# Out:
# retweet rate is  0.0
# Updated retweet rate is  0.0
#
# reputation =  0.2411347518
# Updated reputation =  0.3452380952

# %%
print("\nUpdated data\n")
extract_df
# Out:
# Updated data
#    description  verified   age  followers      mentions  url_ratio  \
# 0            0         0  1487         29  1.6458333333   0.020833
#
#         hashtag  retweet_rate  mean_of_intertweet_delay         SD  \
# 0  0.2708333333           0.0                    4.5625  18.377232
#
#    avg_tweets_day  avg_tweeets_week
# 0         0.03228          0.225958
